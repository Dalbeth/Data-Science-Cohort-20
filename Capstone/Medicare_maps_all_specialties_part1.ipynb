# %% [markdown]
# <a href="https://colab.research.google.com/github/Dalbeth/Data-Science-Cohort-20/blob/main/Capstone/Medicare_maps_all_specialties_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploration of CMS medical provider data
#
# CNM Ingenuity Data Science Cohort 20
# Capstone project
#
# Veronica Luzzi, Favian Jabalera, and Kimberly Butler

# %%
import pandas as pd
import requests
import json
import urllib.parse as up

# %% [markdown]
# ## Data source and information on the data

# %% [markdown]
# Note the address for the CMS data changes monthly, this link will allow the user to update the csv link https://data.cms.gov/provider-data/dataset/mj5m-pzi6#data-table
#
# As this data is updated each month, the team used the June 1st updated data and hosted it on huggingface so it can be reliably available.
#
# Additionally, the data dictionary is available online to allow review of the features in the table

# %%
url = 'https://huggingface.co/datasets/rwcitek/medicare/resolve/main/DAC_NationalDownloadableFile.csv'
url
# Out:
# 'https://huggingface.co/datasets/rwcitek/medicare/resolve/main/DAC_NationalDownloadableFile.csv'

# %%
df = pd.read_csv( url, dtype="str")
df.shape
# Out:
# (3364553, 31)

# %%
df.head()
# Out:
#           NPI  Ind_PAC_ID      Ind_enrl_ID Provider Last Name  \
# 0  1235888272  2365958196  I20250718004023         BAEZ MUNIZ
# 1  1568251114  1153817721  I20260102002504          FULGENCIO
# 2  1578448098  8921583808  I20260329000120             TROCHE
# 3  1205780111  0042786774  I20260420001601            MIRANDA
# 4  1376594978  4587658521  I20260226002111          EISENBERG
#
#   Provider First Name Provider Middle Name suff gndr Cred Med_sch  ...  \
# 0             EDUARDO                  NaN  NaN    M  NaN   OTHER  ...
# 1            TOSCANIA                   Y.  NaN    F   MD   OTHER  ...
# 2           MARISABEL                  NaN  NaN    U  CSW   OTHER  ...
# 3              ISAMAR                  NaN  NaN    F  NaN   OTHER  ...
# 4               DANNY                  NaN  NaN    M   MD   OTHER  ...
#
#   adr_ln_1 adr_ln_2 ln_2_sprs City/Town State ZIP Code Telephone Number  \
# 0      NaN      NaN       NaN    AGUADA    PR    00602       9392994522
# 1      NaN      NaN       NaN    AGUADA    PR    00602       7875890003
# 2      NaN      NaN       NaN  BOQUERON    PR    00622       7873180914
# 3      NaN      NaN       NaN    DORADO    PR    00646       7872435794
# 4      NaN      NaN       NaN    DORADO    PR    00646       2817420469
#
#   ind_assgn grp_assgn                    adrs_id
# 0         Y         M  PR00602XXXXAGXXXXXXXXXX00
# 1         Y         M  PR00602XXXXAGXXXXXXXXXX00
# 2         Y         M  PR00622XXXXBOXXXXXXXXXX00
# 3         Y         M  PR00646XXXXDOXXXXXXXXXX00
# 4         Y         Y  PR00646XXXXDOXXXXXXXXXX00
#
# [5 rows x 31 columns]

# %%
df.tail()
# Out:
#                 NPI  Ind_PAC_ID      Ind_enrl_ID Provider Last Name  \
# 3364548  1104188077  6406154616  I20180507000721        KAMBHAMPATI
# 3364549  1104188077  6406154616  I20180507000721        KAMBHAMPATI
# 3364550  1295198158  3971040619  I20260325003944          KLAWETTER
# 3364551  1871536482  8426152745  I20070327000203            ULLRICK
# 3364552  1871536482  8426152745  I20070327000203            ULLRICK
#
#         Provider First Name Provider Middle Name suff gndr Cred  \
# 3364548           SHIVKUMAR                  NaN  NaN    M   MD
# 3364549           SHIVKUMAR                  NaN  NaN    M   MD
# 3364550             SUSANNE                  NaN  NaN    F  CSW
# 3364551              STEVEN                  NaN  NaN    M   MD
# 3364552              STEVEN                  NaN  NaN    M   MD
#
#                                                    Med_sch  ... adr_ln_1  \
# 3364548    GEORGE WASHINGTON UNIVERSITY SCHOOL OF MEDICINE  ...      NaN
# 3364549    GEORGE WASHINGTON UNIVERSITY SCHOOL OF MEDICINE  ...      NaN
# 3364550                                              OTHER  ...      NaN
# 3364551  UNIVERSITY OF ILLINOIS COLLEGE OF MED (CHI/PEO...  ...      NaN
# 3364552  UNIVERSITY OF ILLINOIS COLLEGE OF MED (CHI/PEO...  ...      NaN
#
#         adr_ln_2 ln_2_sprs        City/Town State   ZIP Code Telephone Number  \
# 3364548      NaN       NaN    EAST NORRITON    PA  194034250       4846227800
# 3364549      NaN       NaN      ELKINS PARK    PA  190272220       2155725200
# 3364550      NaN       NaN           AURORA    CO      80042              NaN
# 3364551      NaN       NaN  MENOMONEE FALLS    WI  530516447       4704126300
# 3364552      NaN       NaN  MENOMONEE FALLS    WI      53051       7702177141
#
#         ind_assgn grp_assgn                    adrs_id
# 3364548         Y         Y  PA194034250EAEINSTASSO301
# 3364549         Y         Y  PA190272220ELMEDICG01X501
# 3364550         M         M  CO800420000AUPOXXXBOXX203
# 3364551         Y         Y  WI530516447MEW187NCTXX300
# 3364552         Y         Y  WI530510000MEW187NCOUR300
#
# [5 rows x 31 columns]

# %%
df.columns.to_list()
# Out:
# ['NPI',
#  'Ind_PAC_ID',
#  'Ind_enrl_ID',
#  'Provider Last Name',
#  'Provider First Name',
#  'Provider Middle Name',
#  'suff',
#  'gndr',
#  'Cred',
#  'Med_sch',
#  'Grd_yr',
#  'pri_spec',
#  'sec_spec_1',
#  'sec_spec_2',
#  'sec_spec_3',
#  'sec_spec_4',
#  'sec_spec_all',
#  'Telehlth',
#  'Facility Name',
#  'org_pac_id',
#  'num_org_mem',
#  'adr_ln_1',
#  'adr_ln_2',
#  'ln_2_sprs',
#  'City/Town',
#  'State',
#  'ZIP Code',
#  'Telephone Number',
#  'ind_assgn',
#  'grp_assgn',
#  'adrs_id']

# %%
df['State'].value_counts()
# Out:
# State
# CA    293016
# FL    250786
# TX    236196
# NY    212664
# PA    166274
# IL    147952
# MI    126737
# OH    122146
# NC    114112
# GA     92443
# NJ     91873
# MA     90051
# MN     89250
# VA     84194
# MD     80836
# WI     79921
# WA     72869
# TN     71615
# AZ     69897
# IN     68431
# MO     62592
# CO     61082
# KY     46724
# SC     46104
# OR     44410
# CT     40857
# LA     36178
# IA     35426
# AL     34834
# KS     34343
# OK     32401
# UT     25713
# MS     24107
# AR     23821
# ID     22238
# NE     21234
# ME     20034
# NV     19392
# WV     18818
# NH     17279
# NM     16855
# SD     13760
# MT     13333
# HI     11943
# DE     11748
# RI     11737
# ND     11356
# DC     10256
# PR     10042
# AK      9789
# VT      7834
# WY      5514
# GU       711
# VI       561
# MP       250
# AS        13
# MH         1
# Name: count, dtype: int64

# %% [markdown]
# ## Creating a dataframe of only New Mexico Providers

# %%
filter = (df['State'] == "NM")
df_nm = df[ filter ]
df_nm
# Out:
#                 NPI  Ind_PAC_ID      Ind_enrl_ID Provider Last Name  \
# 15596    1629459813  4183014012  I20220121000506             BENNET
# 15597    1275772600  2769828151  I20240307002752               WOLF
# 15598    1306340831  6406119304  I20250717001107        YARASHEVICH
# 15599    1407232663  2567760523  I20190409000643            O'NEILL
# 15600    1437118403  1254425101  I20250708000469              QUINN
# ...             ...         ...              ...                ...
# 3363445  1568514289  7719061415  I20240822004270              REDDY
# 3363446  1568514289  7719061415  I20240822004270              REDDY
# 3364103  1568514289  7719061415  I20240822004270              REDDY
# 3364104  1568514289  7719061415  I20240822004270              REDDY
# 3364271  1750742797  8022316736  I20231012002504           REBELLON
#
#         Provider First Name Provider Middle Name suff gndr Cred  \
# 15596             MADELEINE                  NaN  NaN    F  CSW
# 15597               MELISSA                    A  NaN    F  NaN
# 15598                 ALEXI                  NaN  NaN    M   NP
# 15599                GLORIA                  NaN  NaN    F   NP
# 15600                RACHEL                  ANN  NaN    F   MD
# ...                     ...                  ...  ...  ...  ...
# 3363445         HARI CHARAN                  NaN  NaN    M   MD
# 3363446         HARI CHARAN                  NaN  NaN    M   MD
# 3364103         HARI CHARAN                  NaN  NaN    M   MD
# 3364104         HARI CHARAN                  NaN  NaN    M   MD
# 3364271                 ANA                  NaN  NaN    F  NaN
#
#                                                    Med_sch  ...  \
# 15596                                                OTHER  ...
# 15597                                                OTHER  ...
# 15598                                                OTHER  ...
# 15599    UNIVERSITY OF MIAMI, LM MILLER SCHOOL OF MEDICINE  ...
# 15600                                                OTHER  ...
# ...                                                    ...  ...
# 3363445   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...
# 3363446   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...
# 3364103   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...
# 3364104   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...
# 3364271                                              OTHER  ...
#
#                       adr_ln_1 adr_ln_2 ln_2_sprs     City/Town State  \
# 15596                      NaN      NaN       NaN  COCHITI LAKE    NM
# 15597                      NaN      NaN       NaN   ALBUQUERQUE    NM
# 15598                      NaN      NaN       NaN   ALBUQUERQUE    NM
# 15599                      NaN      NaN       NaN   ALBUQUERQUE    NM
# 15600                      NaN      NaN       NaN   ALBUQUERQUE    NM
# ...                        ...      ...       ...           ...   ...
# 3363445                    NaN      NaN       NaN   ALBUQUERQUE    NM
# 3363446                    NaN      NaN       NaN   ALBUQUERQUE    NM
# 3364103  6500 AMERICAS PKWY NE      NaN       NaN   ALBUQUERQUE    NM
# 3364104  6500 AMERICAS PKWY NE      NaN       NaN   ALBUQUERQUE    NM
# 3364271                    NaN      NaN       NaN          TAOS    NM
#
#           ZIP Code Telephone Number ind_assgn grp_assgn  \
# 15596        87083       5057964210         Y         M
# 15597        87102       3232057088         Y         Y
# 15598        87102       7147025145         Y         Y
# 15599        87102       3054509651         Y         M
# 15600        87102       6463980527         Y         Y
# ...            ...              ...       ...       ...
# 3363445      87111       7043347800         M         Y
# 3363446      87111       5207952889         M         Y
# 3364103  871105370       8122826631         M         Y
# 3364104  871105370       4702523422         M         M
# 3364271      87571       8472129339         Y         Y
#
#                            adrs_id
# 15596    NM87083XXXXCOXXXXXXXXXX00
# 15597    NM87102XXXXALXXXXXXXXXX00
# 15598    NM87102XXXXALXXXXXXXXXX00
# 15599    NM87102XXXXALXXXXXXXXXX00
# 15600    NM87102XXXXALXXXXXXXXXX00
# ...                            ...
# 3363445  NM87111XXXXALXXXXXXXXXX00
# 3363446  NM87111XXXXALXXXXXXXXXX00
# 3364103  NM871105370AL6500XNEXX400
# 3364104  NM871105370AL6500XNEXX400
# 3364271  NM87571XXXXTAXXXXXXXXXX00
#
# [16855 rows x 31 columns]

# %%
distinct_count = df_nm['NPI'].nunique()
distinct_count
# Out:
# 10981

# %% [markdown]
# There are ~6000 duplicate providers so we will delete the duplicates that do not provide services to multiple zip codes.  Providers in New Mexico may provide services in more than one zip code.

# %%
# Standardize the ZIP column to 5 digits
df_nm['zip_5'] = df_nm['ZIP Code'].astype(str).str.extract(r'(\d+)', expand=False).str.zfill(5).str[:5]
# Out:
# /tmp/ipykernel_26849/3561545258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nm['zip_5'] = df_nm['ZIP Code'].astype(str).str.extract(r'(\d+)', expand=False).str.zfill(5).str[:5]

# %%
df_nm
# Out:
#                 NPI  Ind_PAC_ID      Ind_enrl_ID Provider Last Name  \
# 15596    1629459813  4183014012  I20220121000506             BENNET
# 15597    1275772600  2769828151  I20240307002752               WOLF
# 15598    1306340831  6406119304  I20250717001107        YARASHEVICH
# 15599    1407232663  2567760523  I20190409000643            O'NEILL
# 15600    1437118403  1254425101  I20250708000469              QUINN
# ...             ...         ...              ...                ...
# 3363445  1568514289  7719061415  I20240822004270              REDDY
# 3363446  1568514289  7719061415  I20240822004270              REDDY
# 3364103  1568514289  7719061415  I20240822004270              REDDY
# 3364104  1568514289  7719061415  I20240822004270              REDDY
# 3364271  1750742797  8022316736  I20231012002504           REBELLON
#
#         Provider First Name Provider Middle Name suff gndr Cred  \
# 15596             MADELEINE                  NaN  NaN    F  CSW
# 15597               MELISSA                    A  NaN    F  NaN
# 15598                 ALEXI                  NaN  NaN    M   NP
# 15599                GLORIA                  NaN  NaN    F   NP
# 15600                RACHEL                  ANN  NaN    F   MD
# ...                     ...                  ...  ...  ...  ...
# 3363445         HARI CHARAN                  NaN  NaN    M   MD
# 3363446         HARI CHARAN                  NaN  NaN    M   MD
# 3364103         HARI CHARAN                  NaN  NaN    M   MD
# 3364104         HARI CHARAN                  NaN  NaN    M   MD
# 3364271                 ANA                  NaN  NaN    F  NaN
#
#                                                    Med_sch  ... adr_ln_2  \
# 15596                                                OTHER  ...      NaN
# 15597                                                OTHER  ...      NaN
# 15598                                                OTHER  ...      NaN
# 15599    UNIVERSITY OF MIAMI, LM MILLER SCHOOL OF MEDICINE  ...      NaN
# 15600                                                OTHER  ...      NaN
# ...                                                    ...  ...      ...
# 3363445   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...      NaN
# 3363446   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...      NaN
# 3364103   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...      NaN
# 3364104   NORTHEASTERN OHIO UNIVERSITY COLLEGE OF MEDICINE  ...      NaN
# 3364271                                              OTHER  ...      NaN
#
#         ln_2_sprs     City/Town State   ZIP Code Telephone Number ind_assgn  \
# 15596         NaN  COCHITI LAKE    NM      87083       5057964210         Y
# 15597         NaN   ALBUQUERQUE    NM      87102       3232057088         Y
# 15598         NaN   ALBUQUERQUE    NM      87102       7147025145         Y
# 15599         NaN   ALBUQUERQUE    NM      87102       3054509651         Y
# 15600         NaN   ALBUQUERQUE    NM      87102       6463980527         Y
# ...           ...           ...   ...        ...              ...       ...
# 3363445       NaN   ALBUQUERQUE    NM      87111       7043347800         M
# 3363446       NaN   ALBUQUERQUE    NM      87111       5207952889         M
# 3364103       NaN   ALBUQUERQUE    NM  871105370       8122826631         M
# 3364104       NaN   ALBUQUERQUE    NM  871105370       4702523422         M
# 3364271       NaN          TAOS    NM      87571       8472129339         Y
#
#         grp_assgn                    adrs_id  zip_5
# 15596           M  NM87083XXXXCOXXXXXXXXXX00  87083
# 15597           Y  NM87102XXXXALXXXXXXXXXX00  87102
# 15598           Y  NM87102XXXXALXXXXXXXXXX00  87102
# 15599           M  NM87102XXXXALXXXXXXXXXX00  87102
# 15600           Y  NM87102XXXXALXXXXXXXXXX00  87102
# ...           ...                        ...    ...
# 3363445         Y  NM87111XXXXALXXXXXXXXXX00  87111
# 3363446         Y  NM87111XXXXALXXXXXXXXXX00  87111
# 3364103         Y  NM871105370AL6500XNEXX400  87110
# 3364104         M  NM871105370AL6500XNEXX400  87110
# 3364271         Y  NM87571XXXXTAXXXXXXXXXX00  87571
#
# [16855 rows x 32 columns]

# %%
df_nm = df_nm.drop_duplicates(subset=['NPI', 'zip_5'])

# %%
df_nm = df_nm.drop(columns=[
    'NPI', 'Ind_PAC_ID', 'Ind_enrl_ID',
    'Provider Middle Name', 'suff', 'Med_sch',
    'Telephone Number', 'ind_assgn', 'grp_assgn',
    'adrs_id', 'Facility Name', 'org_pac_id',
    'num_org_mem', 'adr_ln_1', 'adr_ln_2', 'ln_2_sprs', 'Grd_yr',
    ])
df_nm
# Out:
#         Provider Last Name Provider First Name gndr Cred  \
# 15596               BENNET           MADELEINE    F  CSW
# 15597                 WOLF             MELISSA    F  NaN
# 15598          YARASHEVICH               ALEXI    M   NP
# 15599              O'NEILL              GLORIA    F   NP
# 15600                QUINN              RACHEL    F   MD
# ...                    ...                 ...  ...  ...
# 3357814              GIRON               KELLI    F   NP
# 3357815            BAGWELL               MARIA    F  CSW
# 3363443              REDDY         HARI CHARAN    M   MD
# 3364103              REDDY         HARI CHARAN    M   MD
# 3364271           REBELLON                 ANA    F  NaN
#
#                                                pri_spec sec_spec_1 sec_spec_2  \
# 15596                            CLINICAL SOCIAL WORKER        NaN        NaN
# 15597                           MENTAL HEALTH COUNSELOR        NaN        NaN
# 15598                                NURSE PRACTITIONER        NaN        NaN
# 15599                                NURSE PRACTITIONER        NaN        NaN
# 15600                                   FAMILY PRACTICE        NaN        NaN
# ...                                                 ...        ...        ...
# 3357814                              NURSE PRACTITIONER        NaN        NaN
# 3357815                          CLINICAL SOCIAL WORKER        NaN        NaN
# 3363443                            DIAGNOSTIC RADIOLOGY        NaN        NaN
# 3364103                            DIAGNOSTIC RADIOLOGY        NaN        NaN
# 3364271  REGISTERED DIETITIAN OR NUTRITION PROFESSIONAL        NaN        NaN
#
#         sec_spec_3 sec_spec_4 sec_spec_all Telehlth     City/Town State  \
# 15596          NaN        NaN          NaN        Y  COCHITI LAKE    NM
# 15597          NaN        NaN          NaN        Y   ALBUQUERQUE    NM
# 15598          NaN        NaN          NaN        Y   ALBUQUERQUE    NM
# 15599          NaN        NaN          NaN      NaN   ALBUQUERQUE    NM
# 15600          NaN        NaN          NaN        Y   ALBUQUERQUE    NM
# ...            ...        ...          ...      ...           ...   ...
# 3357814        NaN        NaN          NaN        Y    LAS CRUCES    NM
# 3357815        NaN        NaN          NaN      NaN    LAS CRUCES    NM
# 3363443        NaN        NaN          NaN      NaN   ALBUQUERQUE    NM
# 3364103        NaN        NaN          NaN      NaN   ALBUQUERQUE    NM
# 3364271        NaN        NaN          NaN        Y          TAOS    NM
#
#           ZIP Code  zip_5
# 15596        87083  87083
# 15597        87102  87102
# 15598        87102  87102
# 15599        87102  87102
# 15600        87102  87102
# ...            ...    ...
# 3357814  880011234  88001
# 3357815  880011234  88001
# 3363443      87111  87111
# 3364103  871105370  87110
# 3364271      87571  87571
#
# [14228 rows x 15 columns]

# %% [markdown]
# ## Exploring the types of providers by pulling the 'Cred' column which is a 3 letter code for the provider credentials

# %%
df_nm['Cred'].value_counts()
# Out:
# Cred
# MD     5636
# NP     2592
# PA     1278
# CSW     687
# DO      596
# CNA     563
# PT      437
# OD      245
# CP      183
# DPM     129
# CNM     104
# CH       80
# AU       69
# DC       66
# OT       61
# AA       50
# CNS      36
# PSY      19
# DDS      18
# MNT       9
# Name: count, dtype: int64

# %% [markdown]
# ## Looking at the specialties of interest
#
# This project is focused on geriatric needs.  Primary care is typically by Family Practice, who treat a broad range of ages, and Geriatric Medicine specialists, whose focus is on geriatric patients.  After speaking with our SMEs, Cardiology, Nephrology and Oncology were identified as the most critical specialties that affect geriatric patients.  Seperate dataframes were created for each of these groups of provides.  Additionally, as Physician Assistants and Nurse Practitioners provide care, we explored these providers as well.

# %% [markdown]
# The CMS data is broken down into 5 useful rows for specialties, a primary specialty and 4 rows of secondary specialties. To determine what specialties needed to be combined to create these tables was explored by looking for what specific language was used for each possible specialty row.

# %%
pd.set_option('display.max_rows', None)
df_nm['pri_spec'].value_counts()
# Out:
# pri_spec
# NURSE PRACTITIONER                                2831
# PHYSICIAN ASSISTANT                               1341
# FAMILY PRACTICE                                   1089
# INTERNAL MEDICINE                                  905
# CLINICAL SOCIAL WORKER                             756
# DIAGNOSTIC RADIOLOGY                               650
# MENTAL HEALTH COUNSELOR                            639
# CERTIFIED REGISTERED NURSE ANESTHETIST (CRNA)      570
# EMERGENCY MEDICINE                                 505
# PHYSICAL THERAPIST IN PRIVATE PRACTICE             483
# NEUROLOGY                                          303
# CLINICAL PSYCHOLOGIST                              277
# OPTOMETRY                                          256
# OBSTETRICS/GYNECOLOGY                              251
# GENERAL SURGERY                                    210
# PSYCHIATRY                                         194
# ANESTHESIOLOGY                                     193
# ORTHOPEDIC SURGERY                                 170
# CHIROPRACTIC                                       144
# CARDIOVASCULAR DISEASE (CARDIOLOGY)                141
# OPHTHALMOLOGY                                      140
# PODIATRY                                           135
# PATHOLOGY                                          118
# HOSPITALIST                                        109
# GASTROENTEROLOGY                                   108
# CERTIFIED NURSE MIDWIFE (CNM)                      102
# PEDIATRIC MEDICINE                                  95
# MARRIAGE AND FAMILY THERAPIST                       74
# NEPHROLOGY                                          73
# HEMATOLOGY/ONCOLOGY                                 73
# QUALIFIED AUDIOLOGIST                               73
# CRITICAL CARE (INTENSIVISTS)                        72
# OTOLARYNGOLOGY                                      65
# OCCUPATIONAL THERAPIST IN PRIVATE PRACTICE          65
# DERMATOLOGY                                         63
# PULMONARY DISEASE                                   61
# ANESTHESIOLOGY ASSISTANT                            60
# UROLOGY                                             58
# INFECTIOUS DISEASE                                  54
# QUALIFIED SPEECH LANGUAGE PATHOLOGIST               47
# PHYSICAL MEDICINE AND REHABILITATION                45
# ENDOCRINOLOGY                                       44
# NEUROSURGERY                                        40
# INTERVENTIONAL CARDIOLOGY                           36
# CERTIFIED CLINICAL NURSE SPECIALIST (CNS)           35
# RHEUMATOLOGY                                        32
# RADIATION ONCOLOGY                                  30
# GENERAL PRACTICE                                    28
# REGISTERED DIETITIAN OR NUTRITION PROFESSIONAL      28
# THORACIC SURGERY                                    28
# CARDIAC ELECTROPHYSIOLOGY                           24
# PAIN MANAGEMENT                                     23
# DENTIST                                             22
# VASCULAR SURGERY                                    22
# MEDICAL ONCOLOGY                                    21
# GYNECOLOGICAL ONCOLOGY                              18
# PLASTIC AND RECONSTRUCTIVE SURGERY                  18
# UNDEFINED NON-PHYSICIAN TYPE (SPECIFY)              16
# INTERVENTIONAL RADIOLOGY                            16
# ALLERGY/IMMUNOLOGY                                  16
# HOSPICE/PALLIATIVE CARE                             15
# SLEEP MEDICINE                                      14
# OSTEOPATHIC MANIPULATIVE MEDICINE                   14
# SURGICAL ONCOLOGY                                   12
# HAND SURGERY                                        11
# SPORTS MEDICINE                                     10
# INTERVENTIONAL PAIN MANAGEMENT                       8
# ADDICTION MEDICINE                                   8
# GERIATRIC MEDICINE                                   7
# COLORECTAL SURGERY (PROCTOLOGY)                      7
# HEMATOLOGY                                           6
# PREVENTIVE MEDICINE                                  4
# NEUROPSYCHIATRY                                      4
# ORAL SURGERY                                         3
# GERIATRIC PSYCHIATRY                                 3
# MAXILLOFACIAL SURGERY                                2
# CARDIAC SURGERY                                      2
# MEDICAL GENETICS AND GENOMICS                        2
# PERIPHERAL VASCULAR DISEASE                          1
# Name: count, dtype: int64

# %%
df_nm['sec_spec_1'].value_counts()
# Out:
# sec_spec_1
# INTERNAL MEDICINE                                   383
# HOSPITALIST                                          97
# CRITICAL CARE (INTENSIVISTS)                         90
# FAMILY PRACTICE                                      62
# INTERVENTIONAL RADIOLOGY                             54
# CARDIOVASCULAR DISEASE (CARDIOLOGY)                  51
# EMERGENCY MEDICINE                                   47
# GERIATRIC MEDICINE                                   33
# PEDIATRIC MEDICINE                                   30
# PULMONARY DISEASE                                    29
# PAIN MANAGEMENT                                      25
# GENERAL SURGERY                                      23
# NEPHROLOGY                                           21
# SPORTS MEDICINE                                      19
# ORTHOPEDIC SURGERY                                   19
# INTERVENTIONAL CARDIOLOGY                            19
# ANESTHESIOLOGY                                       18
# GENERAL PRACTICE                                     18
# OBSTETRICS/GYNECOLOGY                                18
# HEMATOLOGY                                           17
# INFECTIOUS DISEASE                                   17
# ADDICTION MEDICINE                                   16
# INTERVENTIONAL PAIN MANAGEMENT                       16
# DIAGNOSTIC RADIOLOGY                                 14
# PSYCHIATRY                                           13
# VASCULAR SURGERY                                     12
# NEUROLOGY                                            11
# HAND SURGERY                                         11
# OSTEOPATHIC MANIPULATIVE MEDICINE                    10
# HOSPICE/PALLIATIVE CARE                               8
# HEMATOLOGY/ONCOLOGY                                   8
# MEDICAL ONCOLOGY                                      7
# PHYSICAL MEDICINE AND REHABILITATION                  7
# NUCLEAR MEDICINE                                      7
# GASTROENTEROLOGY                                      6
# RHEUMATOLOGY                                          6
# SLEEP MEDICINE                                        5
# PREVENTIVE MEDICINE                                   4
# GERIATRIC PSYCHIATRY                                  4
# PLASTIC AND RECONSTRUCTIVE SURGERY                    3
# MICROGRAPHIC DERMATOLOGIC SURGERY (MDS)               3
# CARDIAC SURGERY                                       3
# THORACIC SURGERY                                      3
# ALLERGY/IMMUNOLOGY                                    3
# ENDOCRINOLOGY                                         3
# COLORECTAL SURGERY (PROCTOLOGY)                       2
# OPHTHALMOLOGY                                         2
# MEDICAL TOXICOLOGY                                    2
# ADVANCED HEART FAILURE AND TRANSPLANT CARDIOLOGY      1
# CARDIAC ELECTROPHYSIOLOGY                             1
# NEUROPSYCHIATRY                                       1
# ORAL SURGERY                                          1
# SURGICAL ONCOLOGY                                     1
# MEDICAL GENETICS AND GENOMICS                         1
# UROLOGY                                               1
# EPILEPTOLOGISTS                                       1
# PERIPHERAL VASCULAR DISEASE                           1
# DERMATOLOGY                                           1
# PATHOLOGY                                             1
# Name: count, dtype: int64

# %%
df_nm['sec_spec_2'].value_counts()
# Out:
# sec_spec_2
# INTERNAL MEDICINE                       45
# PULMONARY DISEASE                       11
# SLEEP MEDICINE                           6
# FAMILY PRACTICE                          5
# PEDIATRIC MEDICINE                       5
# HOSPITALIST                              5
# HOSPICE/PALLIATIVE CARE                  4
# INFECTIOUS DISEASE                       4
# HEMATOLOGY/ONCOLOGY                      4
# GERIATRIC MEDICINE                       3
# PAIN MANAGEMENT                          3
# INTERVENTIONAL CARDIOLOGY                2
# MEDICAL ONCOLOGY                         2
# GENERAL SURGERY                          2
# PODIATRY                                 2
# OSTEOPATHIC MANIPULATIVE MEDICINE        2
# PERIPHERAL VASCULAR DISEASE              2
# VASCULAR SURGERY                         1
# ORTHOPEDIC SURGERY                       1
# PLASTIC AND RECONSTRUCTIVE SURGERY       1
# PHYSICAL MEDICINE AND REHABILITATION     1
# GENERAL PRACTICE                         1
# NUCLEAR MEDICINE                         1
# NEUROSURGERY                             1
# MAXILLOFACIAL SURGERY                    1
# NEPHROLOGY                               1
# HAND SURGERY                             1
# PSYCHIATRY                               1
# PREVENTIVE MEDICINE                      1
# RHEUMATOLOGY                             1
# PATHOLOGY                                1
# DERMATOLOGY                              1
# Name: count, dtype: int64

# %%
df_nm['sec_spec_3'].value_counts()
# Out:
# sec_spec_3
# GENERAL PRACTICE                      3
# SLEEP MEDICINE                        3
# PREVENTIVE MEDICINE                   1
# MAXILLOFACIAL SURGERY                 1
# INTERVENTIONAL CARDIOLOGY             1
# PULMONARY DISEASE                     1
# OTOLARYNGOLOGY                        1
# PLASTIC AND RECONSTRUCTIVE SURGERY    1
# OSTEOPATHIC MANIPULATIVE MEDICINE     1
# HOSPICE/PALLIATIVE CARE               1
# Name: count, dtype: int64

# %%
df_nm['sec_spec_4'].value_counts()
# Out:
# sec_spec_4
# INTERNAL MEDICINE    1
# Name: count, dtype: int64

# %% [markdown]
# Nurse Practitioners and Physcian Assistants are shown as a primary specialty, it is unclear from this data if secondary specialties are recorded for NP and PAs. So next I will explore this.

# %%
pd.reset_option('display.max_rows')

# %%
df_nmNPs = df_nm[df_nm['pri_spec'] == 'NURSE PRACTITIONER']
df_nmNPs
# Out:
#         Provider Last Name Provider First Name gndr Cred            pri_spec  \
# 15598          YARASHEVICH               ALEXI    M   NP  NURSE PRACTITIONER
# 15599              O'NEILL              GLORIA    F   NP  NURSE PRACTITIONER
# 15602             YUFENYUY              STELLA    F  NaN  NURSE PRACTITIONER
# 15603              JOHNSON             SHAKITA    F   NP  NURSE PRACTITIONER
# 15606              YNIGUEZ             ANTHONY    M   NP  NURSE PRACTITIONER
# ...                    ...                 ...  ...  ...                 ...
# 3345490           WILLIAMS              ALFRED    M   NP  NURSE PRACTITIONER
# 3346434    MCAFEE-TRUJILLO               KORIE    F   NP  NURSE PRACTITIONER
# 3355485         PALFREYMAN             KRISTIE    F   NP  NURSE PRACTITIONER
# 3357813              HAILE             GHIRMAY    M   NP  NURSE PRACTITIONER
# 3357814              GIRON               KELLI    F   NP  NURSE PRACTITIONER
#
#         sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4 sec_spec_all Telehlth  \
# 15598          NaN        NaN        NaN        NaN          NaN        Y
# 15599          NaN        NaN        NaN        NaN          NaN      NaN
# 15602          NaN        NaN        NaN        NaN          NaN        Y
# 15603          NaN        NaN        NaN        NaN          NaN      NaN
# 15606          NaN        NaN        NaN        NaN          NaN        Y
# ...            ...        ...        ...        ...          ...      ...
# 3345490        NaN        NaN        NaN        NaN          NaN      NaN
# 3346434        NaN        NaN        NaN        NaN          NaN      NaN
# 3355485        NaN        NaN        NaN        NaN          NaN      NaN
# 3357813        NaN        NaN        NaN        NaN          NaN        Y
# 3357814        NaN        NaN        NaN        NaN          NaN        Y
#
#            City/Town State   ZIP Code  zip_5
# 15598    ALBUQUERQUE    NM      87102  87102
# 15599    ALBUQUERQUE    NM      87102  87102
# 15602    ALBUQUERQUE    NM      87102  87102
# 15603    ALBUQUERQUE    NM      87102  87102
# 15606    ALBUQUERQUE    NM      87102  87102
# ...              ...   ...        ...    ...
# 3345490    SAN FIDEL    NM      87049  87049
# 3346434   RIO RANCHO    NM      87174  87174
# 3355485  ALBUQUERQUE    NM  871992200  87199
# 3357813   LAS CRUCES    NM  880011234  88001
# 3357814   LAS CRUCES    NM  880011234  88001
#
# [2831 rows x 15 columns]

# %%
df_nmNPs['sec_spec_1'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
df_nmPAs = df_nm[df_nm['pri_spec'] == 'PHYSICIAN ASSISTANT']
df_nmPAs
# Out:
#         Provider Last Name Provider First Name gndr Cred             pri_spec  \
# 62453                 BACA            SAMANTHA    F   PA  PHYSICIAN ASSISTANT
# 62459                  FOX             LINDSAY    F   PA  PHYSICIAN ASSISTANT
# 137516              ROYBAL           GABRIELLE    F   PA  PHYSICIAN ASSISTANT
# 137522            MARTINEZ                ERIN    F   PA  PHYSICIAN ASSISTANT
# 143996               PARKE              DALTON    M   PA  PHYSICIAN ASSISTANT
# ...                    ...                 ...  ...  ...                  ...
# 3341328             DEVLIN                LYNN    F   PA  PHYSICIAN ASSISTANT
# 3342001              JARKA               LYDIA    F   PA  PHYSICIAN ASSISTANT
# 3345186             GRIEGO             PHILLIP    M   PA  PHYSICIAN ASSISTANT
# 3349370           WENTLING                LISA    F   PA  PHYSICIAN ASSISTANT
# 3350865               CHAN                ALEC    M   PA  PHYSICIAN ASSISTANT
#
#         sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4 sec_spec_all Telehlth  \
# 62453          NaN        NaN        NaN        NaN          NaN      NaN
# 62459          NaN        NaN        NaN        NaN          NaN      NaN
# 137516         NaN        NaN        NaN        NaN          NaN      NaN
# 137522         NaN        NaN        NaN        NaN          NaN      NaN
# 143996         NaN        NaN        NaN        NaN          NaN      NaN
# ...            ...        ...        ...        ...          ...      ...
# 3341328        NaN        NaN        NaN        NaN          NaN      NaN
# 3342001        NaN        NaN        NaN        NaN          NaN      NaN
# 3345186        NaN        NaN        NaN        NaN          NaN      NaN
# 3349370        NaN        NaN        NaN        NaN          NaN      NaN
# 3350865        NaN        NaN        NaN        NaN          NaN      NaN
#
#                City/Town State   ZIP Code  zip_5
# 62453        ALBUQUERQUE    NM  871310001  87131
# 62459        ALBUQUERQUE    NM  871310001  87131
# 137516       ALBUQUERQUE    NM  871065205  87106
# 137522       ALBUQUERQUE    NM  871065205  87106
# 143996        FARMINGTON    NM  874015638  87401
# ...                  ...   ...        ...    ...
# 3341328         SANTA FE    NM  875042267  87504
# 3342001  TIERRA AMARILLA    NM  875750250  87575
# 3345186            DIXON    NM      87527  87527
# 3349370         CIMARRON    NM  877140625  87714
# 3350865         SANTA FE    NM      87502  87502
#
# [1341 rows x 15 columns]

# %%
df_nmPAs['sec_spec_1'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %% [markdown]
# There is no secondary specialties recorded for either PAs or NPs which limits the utility of this data for evaluating practice beyond physicians

# %% [markdown]
# Exploring geriatric providers, this set is specific to the term "GERIATRIC MEDICINE' in any of the specialty columns.  There are providers that list GERIATRIC MEDICINE as a primary (pri_spec), secondary spec 1 and 2 and sec_spec_all.

# %%
df_nmger = df_nm.loc[(df_nm == 'GERIATRIC MEDICINE').any(axis=1)]
df_nmger
# Out:
#         Provider Last Name Provider First Name gndr Cred  \
# 15685               RHYMES                JILL    F   MD
# 174501              LEAMON            GEORGINA    F   MD
# 185550              FEAGAN              JOSEPH    M   DO
# 306624               DURAN               JESUS    M   MD
# 470444            WILLIAMS              GEORGE    M   DO
# 578441               MAHDI                SYED    M   MD
# 612715             OBISIKE                UCHE    M   MD
# 819581              ERINLE             AYODELE    M   MD
# 1077479             FEAGAN              JOSEPH    M   DO
# 1268600              LAMBA           DHIRENDRA    M   MD
# 1331496         WILAMOWSKA           KATARZYNA    F   MD
# 1341659            BUDHWAR               NITIN    M   MD
# 1342266             SCRASE               DAVID    M   MD
# 1342687             HERMAN               CARLA    F   MD
# 1342726            KNOEFEL              JANICE    F   MD
# 1342749            DERADKE           ALEXANDER    M   DO
# 1342756           WILLIAMS               KEVIN    M   MD
# 1342872              NEALE               DEVON    F   MD
# 1345698            METZLER                ERIC    M   MD
# 1436411             ALLADI              VIKRAM    M   MD
# 1727680           WILLIAMS               KEVIN    M   MD
# 2086205     DELGADO FELIPA            JENNIFER    F   MD
# 2162509              CHAVA             PRAVEEN    M   MD
# 2175853          CENTENERA             LEANDRO    M   MD
# 2188536           HEMPHILL               DAVID    M   MD
# 2193156            OBISIKE                UCHE    M   MD
# 2193171           BARDWELL             AVELINA    F   MD
# 2218223               BOND                JOHN    M   MD
# 2262297        KNOBELSDORF              SHARON    F  NaN
# 2280733             GARCIA                 ANN    F   MD
# 2280743             RHYMES                JILL    F   MD
# 2280744         SILVERHART               JULIE    F   MD
# 2334384           STANDOLI           FRANCESCO    M   MD
# 2444866            METZLER                ERIC    M   MD
# 2619839             ALLADI              VIKRAM    M   MD
# 2705421               SAAD                ABDO    M   MD
# 2776887              ROCHE             RICHARD    M   MD
# 2863562              ROCHE             RICHARD    M   MD
# 3000812              RALLS           FRANCISCO    M   MD
# 3081376            TANNOUS              TOUFIC    M   MD
# 3142064              BUNGO           CHRISTINA    F   DO
# 3176892              MAHDI                SYED    M   MD
# 3304290            ADEDEJI            ADEKUNLE    M   MD
#
#                         pri_spec                    sec_spec_1  \
# 15685          INTERNAL MEDICINE            GERIATRIC MEDICINE
# 174501         INTERNAL MEDICINE            GERIATRIC MEDICINE
# 185550           FAMILY PRACTICE            GERIATRIC MEDICINE
# 306624         INTERNAL MEDICINE            GERIATRIC MEDICINE
# 470444           FAMILY PRACTICE            GERIATRIC MEDICINE
# 578441         INTERNAL MEDICINE            GERIATRIC MEDICINE
# 612715         INTERNAL MEDICINE            GERIATRIC MEDICINE
# 819581                NEPHROLOGY            GERIATRIC MEDICINE
# 1077479          FAMILY PRACTICE            GERIATRIC MEDICINE
# 1268600       EMERGENCY MEDICINE            GERIATRIC MEDICINE
# 1331496          FAMILY PRACTICE            GERIATRIC MEDICINE
# 1341659          FAMILY PRACTICE            GERIATRIC MEDICINE
# 1342266       GERIATRIC MEDICINE             INTERNAL MEDICINE
# 1342687       GERIATRIC MEDICINE             INTERNAL MEDICINE
# 1342726                NEUROLOGY            GERIATRIC MEDICINE
# 1342749       GERIATRIC MEDICINE             INTERNAL MEDICINE
# 1342756          FAMILY PRACTICE          DIAGNOSTIC RADIOLOGY
# 1342872  HOSPICE/PALLIATIVE CARE            GERIATRIC MEDICINE
# 1345698          FAMILY PRACTICE            GERIATRIC MEDICINE
# 1436411        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 1727680          FAMILY PRACTICE          DIAGNOSTIC RADIOLOGY
# 2086205          FAMILY PRACTICE            GERIATRIC MEDICINE
# 2162509          FAMILY PRACTICE            GERIATRIC MEDICINE
# 2175853       GERIATRIC MEDICINE         OBSTETRICS/GYNECOLOGY
# 2188536        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 2193156        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 2193171        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 2218223          FAMILY PRACTICE            GERIATRIC MEDICINE
# 2262297       GERIATRIC MEDICINE  CRITICAL CARE (INTENSIVISTS)
# 2280733       GERIATRIC MEDICINE                           NaN
# 2280743        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 2280744          FAMILY PRACTICE            GERIATRIC MEDICINE
# 2334384          FAMILY PRACTICE            GERIATRIC MEDICINE
# 2444866          FAMILY PRACTICE            GERIATRIC MEDICINE
# 2619839        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 2705421         GASTROENTEROLOGY            GERIATRIC MEDICINE
# 2776887        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 2863562        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 3000812           SLEEP MEDICINE               FAMILY PRACTICE
# 3081376      HEMATOLOGY/ONCOLOGY            GERIATRIC MEDICINE
# 3142064       GERIATRIC MEDICINE               FAMILY PRACTICE
# 3176892        INTERNAL MEDICINE            GERIATRIC MEDICINE
# 3304290          FAMILY PRACTICE            GERIATRIC MEDICINE
#
#                       sec_spec_2               sec_spec_3         sec_spec_4  \
# 15685                        NaN                      NaN                NaN
# 174501                       NaN                      NaN                NaN
# 185550                       NaN                      NaN                NaN
# 306624                       NaN                      NaN                NaN
# 470444                       NaN                      NaN                NaN
# 578441                       NaN                      NaN                NaN
# 612715        PEDIATRIC MEDICINE                      NaN                NaN
# 819581                       NaN                      NaN                NaN
# 1077479                      NaN                      NaN                NaN
# 1268600        INTERNAL MEDICINE                      NaN                NaN
# 1331496                      NaN                      NaN                NaN
# 1341659                      NaN                      NaN                NaN
# 1342266                      NaN                      NaN                NaN
# 1342687                      NaN                      NaN                NaN
# 1342726                      NaN                      NaN                NaN
# 1342749                      NaN                      NaN                NaN
# 1342756       GERIATRIC MEDICINE                      NaN                NaN
# 1342872        INTERNAL MEDICINE                      NaN                NaN
# 1345698  HOSPICE/PALLIATIVE CARE                      NaN                NaN
# 1436411                      NaN                      NaN                NaN
# 1727680       GERIATRIC MEDICINE                      NaN                NaN
# 2086205                      NaN                      NaN                NaN
# 2162509                      NaN                      NaN                NaN
# 2175853                      NaN                      NaN                NaN
# 2188536                      NaN                      NaN                NaN
# 2193156       PEDIATRIC MEDICINE                      NaN                NaN
# 2193171                      NaN                      NaN                NaN
# 2218223                      NaN                      NaN                NaN
# 2262297                      NaN                      NaN                NaN
# 2280733                      NaN                      NaN                NaN
# 2280743                      NaN                      NaN                NaN
# 2280744                      NaN                      NaN                NaN
# 2334384  HOSPICE/PALLIATIVE CARE                      NaN                NaN
# 2444866  HOSPICE/PALLIATIVE CARE                      NaN                NaN
# 2619839                      NaN                      NaN                NaN
# 2705421        INTERNAL MEDICINE                      NaN                NaN
# 2776887                      NaN                      NaN                NaN
# 2863562                      NaN                      NaN                NaN
# 3000812       GERIATRIC MEDICINE  HOSPICE/PALLIATIVE CARE  INTERNAL MEDICINE
# 3081376                      NaN                      NaN                NaN
# 3142064                      NaN                      NaN                NaN
# 3176892                      NaN                      NaN                NaN
# 3304290                      NaN                      NaN                NaN
#
#                                               sec_spec_all Telehlth  \
# 15685                                   GERIATRIC MEDICINE        Y
# 174501                                  GERIATRIC MEDICINE        Y
# 185550                                  GERIATRIC MEDICINE      NaN
# 306624                                  GERIATRIC MEDICINE        Y
# 470444                                  GERIATRIC MEDICINE      NaN
# 578441                                  GERIATRIC MEDICINE      NaN
# 612715              GERIATRIC MEDICINE, PEDIATRIC MEDICINE      NaN
# 819581                                  GERIATRIC MEDICINE        Y
# 1077479                                 GERIATRIC MEDICINE      NaN
# 1268600              GERIATRIC MEDICINE, INTERNAL MEDICINE      NaN
# 1331496                                 GERIATRIC MEDICINE      NaN
# 1341659                                 GERIATRIC MEDICINE      NaN
# 1342266                                  INTERNAL MEDICINE      NaN
# 1342687                                  INTERNAL MEDICINE      NaN
# 1342726                                 GERIATRIC MEDICINE        Y
# 1342749                                  INTERNAL MEDICINE        Y
# 1342756           DIAGNOSTIC RADIOLOGY, GERIATRIC MEDICINE      NaN
# 1342872              GERIATRIC MEDICINE, INTERNAL MEDICINE        Y
# 1345698        GERIATRIC MEDICINE, HOSPICE/PALLIATIVE CARE      NaN
# 1436411                                 GERIATRIC MEDICINE      NaN
# 1727680           DIAGNOSTIC RADIOLOGY, GERIATRIC MEDICINE      NaN
# 2086205                                 GERIATRIC MEDICINE      NaN
# 2162509                                 GERIATRIC MEDICINE      NaN
# 2175853                              OBSTETRICS/GYNECOLOGY      NaN
# 2188536                                 GERIATRIC MEDICINE      NaN
# 2193156             GERIATRIC MEDICINE, PEDIATRIC MEDICINE      NaN
# 2193171                                 GERIATRIC MEDICINE      NaN
# 2218223                                 GERIATRIC MEDICINE        Y
# 2262297                       CRITICAL CARE (INTENSIVISTS)      NaN
# 2280733                                                NaN        Y
# 2280743                                 GERIATRIC MEDICINE        Y
# 2280744                                 GERIATRIC MEDICINE        Y
# 2334384        GERIATRIC MEDICINE, HOSPICE/PALLIATIVE CARE        Y
# 2444866        GERIATRIC MEDICINE, HOSPICE/PALLIATIVE CARE      NaN
# 2619839                                 GERIATRIC MEDICINE      NaN
# 2705421              GERIATRIC MEDICINE, INTERNAL MEDICINE      NaN
# 2776887                                 GERIATRIC MEDICINE      NaN
# 2863562                                 GERIATRIC MEDICINE      NaN
# 3000812  FAMILY PRACTICE, GERIATRIC MEDICINE, HOSPICE/P...        Y
# 3081376                                 GERIATRIC MEDICINE        Y
# 3142064                                    FAMILY PRACTICE        Y
# 3176892                                 GERIATRIC MEDICINE      NaN
# 3304290                                 GERIATRIC MEDICINE        Y
#
#                      City/Town State   ZIP Code  zip_5
# 15685              ALBUQUERQUE    NM      87110  87110
# 174501                ESPANOLA    NM  875322724  87532
# 185550                  GRANTS    NM  870202118  87020
# 306624              LAS CRUCES    NM  880118154  88011
# 470444                  DEMING    NM  880303755  88030
# 578441             SILVER CITY    NM  880617251  88061
# 612715              RIO RANCHO    NM  871241519  87124
# 819581                  GALLUP    NM  873015881  87301
# 1077479                 GALLUP    NM  873015683  87301
# 1268600                 CLOVIS    NM  881019412  88101
# 1331496                 CLOVIS    NM  881012011  88101
# 1341659            ALBUQUERQUE    NM  871062719  87106
# 1342266            ALBUQUERQUE    NM  871062719  87106
# 1342687            ALBUQUERQUE    NM  871062719  87106
# 1342726            ALBUQUERQUE    NM  871062719  87106
# 1342749            ALBUQUERQUE    NM  871062719  87106
# 1342756            ALBUQUERQUE    NM  871062719  87106
# 1342872            ALBUQUERQUE    NM  871062719  87106
# 1345698            ALBUQUERQUE    NM  871122607  87112
# 1436411             RIO RANCHO    NM  871244740  87124
# 1727680             RIO RANCHO    NM  871442100  87144
# 2086205             RIO RANCHO    NM  871245906  87124
# 2162509               PORTALES    NM  881309054  88130
# 2175853            ALBUQUERQUE    NM  871096746  87109
# 2188536               CORRALES    NM  870488663  87048
# 2193156               SANTA FE    NM  875057601  87505
# 2193171               SANTA FE    NM  875057601  87505
# 2218223            ALBUQUERQUE    NM  871145915  87114
# 2262297            ALBUQUERQUE    NM  871112665  87111
# 2280733               SANTA FE    NM  875058602  87505
# 2280743               SANTA FE    NM  875058602  87505
# 2280744               SANTA FE    NM  875058602  87505
# 2334384            ALBUQUERQUE    NM  871094397  87109
# 2444866            ALBUQUERQUE    NM  871081334  87108
# 2619839            ALBUQUERQUE    NM  871023619  87102
# 2705421             FARMINGTON    NM  874016113  87401
# 2776887            ALBUQUERQUE    NM  871094318  87109
# 2863562            ALBUQUERQUE    NM  871023668  87102
# 3000812  TRUTH OR CONSEQUENCES    NM  879011954  87901
# 3081376            ALBUQUERQUE    NM  871107613  87110
# 3142064            ALBUQUERQUE    NM  871112310  87111
# 3176892                 DEMING    NM  880304000  88030
# 3304290  TRUTH OR CONSEQUENCES    NM  879013198  87901

# %% [markdown]
# As family practice providers which are primary providers often treat geriatric patients, I pulled the providers listed as "FAMILY PRACTICE' in any of the specialty columns.  There are providers that list FAMILY PRACTICE as a primary (pri_spec), secondary spec 1 and 2 and sec_spec_all.

# %%
df_nmfam = df_nm.loc[(df_nm == 'FAMILY PRACTICE').any(axis=1)]
df_nmfam
# Out:
#         Provider Last Name Provider First Name gndr Cred            pri_spec  \
# 15600                QUINN              RACHEL    F   MD     FAMILY PRACTICE
# 15660           STOLARCZYK                LISA    F   MD     FAMILY PRACTICE
# 15661                YASIN               FARES    M   MD     FAMILY PRACTICE
# 15663            BANIKARIM               EFFAT    F   MD     FAMILY PRACTICE
# 15682             GALLEGOS            EMMANUEL    M   MD  EMERGENCY MEDICINE
# ...                    ...                 ...  ...  ...                 ...
# 3356890        GAUVEY KERN               KEVIN    M   MD     FAMILY PRACTICE
# 3356894                RAO              AMRITA    F   MD     FAMILY PRACTICE
# 3356898             CARUSO             DOMINIC    M   MD     FAMILY PRACTICE
# 3356901               BACK              JOSHUA    M   MD     FAMILY PRACTICE
# 3356906             JENSEN              ANDREW    M   MD     FAMILY PRACTICE
#
#               sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4     sec_spec_all  \
# 15600                NaN        NaN        NaN        NaN              NaN
# 15660                NaN        NaN        NaN        NaN              NaN
# 15661                NaN        NaN        NaN        NaN              NaN
# 15663                NaN        NaN        NaN        NaN              NaN
# 15682    FAMILY PRACTICE        NaN        NaN        NaN  FAMILY PRACTICE
# ...                  ...        ...        ...        ...              ...
# 3356890              NaN        NaN        NaN        NaN              NaN
# 3356894              NaN        NaN        NaN        NaN              NaN
# 3356898              NaN        NaN        NaN        NaN              NaN
# 3356901              NaN        NaN        NaN        NaN              NaN
# 3356906              NaN        NaN        NaN        NaN              NaN
#
#         Telehlth    City/Town State   ZIP Code  zip_5
# 15600          Y  ALBUQUERQUE    NM      87102  87102
# 15660          Y  ALBUQUERQUE    NM      87110  87110
# 15661        NaN  ALBUQUERQUE    NM      87110  87110
# 15663        NaN  ALBUQUERQUE    NM      87110  87110
# 15682        NaN  ALBUQUERQUE    NM      87110  87110
# ...          ...          ...   ...        ...    ...
# 3356890      NaN         ZUNI    NM  873270467  87327
# 3356894      NaN         ZUNI    NM  873270467  87327
# 3356898      NaN         ZUNI    NM  873270467  87327
# 3356901      NaN         ZUNI    NM  873270467  87327
# 3356906      NaN         ZUNI    NM  873270467  87327
#
# [1156 rows x 15 columns]

# %% [markdown]
# Next, I created the specialist dataframes.  The cardiac specialties that are included are: CARDIOVASCULAR DISEASE (CARDIOLOGY), INTERVENTIONAL CARDIOLOGY, and CARDIAC ELECTROPHYSIOLOGY. As with the other searches, this included the primary specialty and all secondary specialties.

# %%
cardiac_specs = ['CARDIOVASCULAR DISEASE (CARDIOLOGY)', 'INTERVENTIONAL CARDIOLOGY', 'CARDIAC ELECTROPHYSIOLOGY']

df_nmcard = df_nm.loc[df_nm.isin(cardiac_specs).any(axis=1)]
df_nmcard
# Out:
#         Provider Last Name Provider First Name gndr Cred  \
# 15749            INCORVATI              DENNIS    M   DO
# 15754                 GALA               KETAN    M   MD
# 174516              REHMAN               AAMER    M   MD
# 174539                CAMP             PHILLIP    M   MD
# 185536               WOODS            RODERICK    M   MD
# ...                    ...                 ...  ...  ...
# 3176904              ANWAR             KHAWAJA    M   MD
# 3333108    O'DONNELL-SMITH                MARY    F   MD
# 3333159              LEVIN             CHARLES    M   MD
# 3333160           MAYFIELD               JACOB    M   MD
# 3333211             ELLINI              KAYVAN    M   MD
#
#                                     pri_spec  \
# 15749    CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 15754    CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 174516             INTERVENTIONAL CARDIOLOGY
# 174539   CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 185536   CARDIOVASCULAR DISEASE (CARDIOLOGY)
# ...                                      ...
# 3176904  CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 3333108  CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 3333159  CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 3333160  CARDIOVASCULAR DISEASE (CARDIOLOGY)
# 3333211  CARDIOVASCULAR DISEASE (CARDIOLOGY)
#
#                                   sec_spec_1         sec_spec_2 sec_spec_3  \
# 15749                                    NaN                NaN        NaN
# 15754                                    NaN                NaN        NaN
# 174516   CARDIOVASCULAR DISEASE (CARDIOLOGY)  INTERNAL MEDICINE        NaN
# 174539                                   NaN                NaN        NaN
# 185536                     INTERNAL MEDICINE                NaN        NaN
# ...                                      ...                ...        ...
# 3176904                    INTERNAL MEDICINE                NaN        NaN
# 3333108                                  NaN                NaN        NaN
# 3333159                                  NaN                NaN        NaN
# 3333160                    INTERNAL MEDICINE                NaN        NaN
# 3333211            INTERVENTIONAL CARDIOLOGY                NaN        NaN
#
#         sec_spec_4                                       sec_spec_all  \
# 15749          NaN                                                NaN
# 15754          NaN                                                NaN
# 174516         NaN  CARDIOVASCULAR DISEASE (CARDIOLOGY), INTERNAL ...
# 174539         NaN                                                NaN
# 185536         NaN                                  INTERNAL MEDICINE
# ...            ...                                                ...
# 3176904        NaN                                  INTERNAL MEDICINE
# 3333108        NaN                                                NaN
# 3333159        NaN                                                NaN
# 3333160        NaN                                  INTERNAL MEDICINE
# 3333211        NaN                          INTERVENTIONAL CARDIOLOGY
#
#         Telehlth    City/Town State   ZIP Code  zip_5
# 15749          Y     SANTA FE    NM      87505  87505
# 15754          Y     SANTA FE    NM      87505  87505
# 174516       NaN     ESPANOLA    NM  875322724  87532
# 174539       NaN     ESPANOLA    NM  875322724  87532
# 185536       NaN       GRANTS    NM  870202118  87020
# ...          ...          ...   ...        ...    ...
# 3176904      NaN       DEMING    NM  880304000  88030
# 3333108      NaN  ALBUQUERQUE    NM      87125  87125
# 3333159      NaN  ALBUQUERQUE    NM  871256666  87125
# 3333160      NaN  ALBUQUERQUE    NM  871256666  87125
# 3333211      NaN  ALBUQUERQUE    NM  871256666  87125
#
# [216 rows x 15 columns]

# %% [markdown]
# As we have a strong interest in nephrology, I grabbed the nephrology specialists in case we get a chance to explore these as well. This search is simple as there is only one term for NEPHROLOGY.

# %%
df_nmneph = df_nm.loc[(df_nm == 'NEPHROLOGY').any(axis=1)]
df_nmneph
# Out:
#         Provider Last Name Provider First Name gndr Cred           pri_spec  \
# 15678             SIMFUKWE              MAYBIN    M   MD         NEPHROLOGY
# 440806              GARCIA               PABLO    M   MD         NEPHROLOGY
# 819580            DESHMUKH              SUSHIL    M   DO         NEPHROLOGY
# 819581              ERINLE             AYODELE    M   MD         NEPHROLOGY
# 819583               HENAO                JOSE    M   MD         NEPHROLOGY
# ...                    ...                 ...  ...  ...                ...
# 3317260                LAM            FRANKLIN    M   MD         NEPHROLOGY
# 3317278             PANDYA              MANISH    M   MD  INTERNAL MEDICINE
# 3317304     SOLANO BAYARDO           ALEJANDRO    M   MD         NEPHROLOGY
# 3317314              BEVAN                MARK    M   MD  INTERNAL MEDICINE
# 3317319            ADENEYE              DANIEL    M   MD         NEPHROLOGY
#
#                  sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4  \
# 15678     INTERNAL MEDICINE        NaN        NaN        NaN
# 440806    INTERNAL MEDICINE        NaN        NaN        NaN
# 819580    INTERNAL MEDICINE        NaN        NaN        NaN
# 819581   GERIATRIC MEDICINE        NaN        NaN        NaN
# 819583                  NaN        NaN        NaN        NaN
# ...                     ...        ...        ...        ...
# 3317260   INTERNAL MEDICINE        NaN        NaN        NaN
# 3317278          NEPHROLOGY        NaN        NaN        NaN
# 3317304                 NaN        NaN        NaN        NaN
# 3317314          NEPHROLOGY        NaN        NaN        NaN
# 3317319   INTERNAL MEDICINE        NaN        NaN        NaN
#
#                sec_spec_all Telehlth    City/Town State   ZIP Code  zip_5
# 15678     INTERNAL MEDICINE        Y  ALBUQUERQUE    NM      87110  87110
# 440806    INTERNAL MEDICINE      NaN  ALBUQUERQUE    NM      87106  87106
# 819580    INTERNAL MEDICINE      NaN       GALLUP    NM  873015881  87301
# 819581   GERIATRIC MEDICINE        Y       GALLUP    NM  873015881  87301
# 819583                  NaN        Y       GALLUP    NM  873015881  87301
# ...                     ...      ...          ...   ...        ...    ...
# 3317260   INTERNAL MEDICINE      NaN     SHIPROCK    NM  874200160  87420
# 3317278          NEPHROLOGY        Y     SHIPROCK    NM  874200160  87420
# 3317304                 NaN      NaN     SHIPROCK    NM  874200160  87420
# 3317314          NEPHROLOGY      NaN     SHIPROCK    NM  874200160  87420
# 3317319   INTERNAL MEDICINE      NaN     SHIPROCK    NM  874200160  87420
#
# [95 rows x 15 columns]

# %% [markdown]
# Finally, I pulled oncology specialties in case we get a chance to explore a third interest. The specialties for oncology are: HEMATOLOGY/ONCOLOGY, SURGICAL ONCOLOGY, MEDICAL ONCOLOGY.

# %%
onco_specs = ['HEMATOLOGY/ONCOLOGY', 'SURGICAL ONCOLOGY', 'MEDICAL ONCOLOGY']

df_nmonco = df_nm.loc[df_nm.isin(onco_specs).any(axis=1)]
df_nmonco
# Out:
#         Provider Last Name Provider First Name gndr Cred             pri_spec  \
# 166126    KHORSAND-SAHBAIE              MASOUD    M   MD  HEMATOLOGY/ONCOLOGY
# 290641              BINDER               ETHAN    M   MD  HEMATOLOGY/ONCOLOGY
# 440802               KUMAR                ATUL    M   MD     MEDICAL ONCOLOGY
# 440805              FOUCAR             CHARLES    M   MD           HEMATOLOGY
# 578496             SHAHEEN            MONTASER    M   MD  HEMATOLOGY/ONCOLOGY
# ...                    ...                 ...  ...  ...                  ...
# 3081383          NWABUDIKE             STANLEY    M   MD  HEMATOLOGY/ONCOLOGY
# 3081387        MUNOH KENNE                FOMA    M   MD  HEMATOLOGY/ONCOLOGY
# 3333118             PALMER                GARY    M   MD     MEDICAL ONCOLOGY
# 3333177             DOWNIE            BENJAMIN    M   MD     MEDICAL ONCOLOGY
# 3333184             BINDER               ETHAN    M   MD  HEMATOLOGY/ONCOLOGY
#
#                       sec_spec_1 sec_spec_2 sec_spec_3 sec_spec_4  \
# 166126                       NaN        NaN        NaN        NaN
# 290641                       NaN        NaN        NaN        NaN
# 440802         INTERNAL MEDICINE        NaN        NaN        NaN
# 440805          MEDICAL ONCOLOGY        NaN        NaN        NaN
# 578496         INTERNAL MEDICINE        NaN        NaN        NaN
# ...                          ...        ...        ...        ...
# 3081383                      NaN        NaN        NaN        NaN
# 3081387                      NaN        NaN        NaN        NaN
# 3333118                      NaN        NaN        NaN        NaN
# 3333177  HOSPICE/PALLIATIVE CARE        NaN        NaN        NaN
# 3333184                      NaN        NaN        NaN        NaN
#
#                     sec_spec_all Telehlth    City/Town State   ZIP Code  zip_5
# 166126                       NaN        Y     CARLSBAD    NM  882205713  88220
# 290641                       NaN        Y  ALBUQUERQUE    NM  871064930  87106
# 440802         INTERNAL MEDICINE        Y  ALBUQUERQUE    NM      87106  87106
# 440805          MEDICAL ONCOLOGY        Y  ALBUQUERQUE    NM      87106  87106
# 578496         INTERNAL MEDICINE        Y  SILVER CITY    NM  880617251  88061
# ...                          ...      ...          ...   ...        ...    ...
# 3081383                      NaN        Y  ALBUQUERQUE    NM  871107613  87110
# 3081387                      NaN        Y  ALBUQUERQUE    NM  871107613  87110
# 3333118                      NaN      NaN  ALBUQUERQUE    NM      87125  87125
# 3333177  HOSPICE/PALLIATIVE CARE        Y  ALBUQUERQUE    NM  871256666  87125
# 3333184                      NaN        Y  ALBUQUERQUE    NM  871256666  87125
#
# [117 rows x 15 columns]

# %% [markdown]
# ## Automate geocoding and mapping
#
# The zip codes will be used to get the latitude and longitude for each provider to allow interactive mapping.  Two methods of interactive mapping were used.  The first creates nicer maps, but can interact poorly in live display and with different browsers. However, when opened in at least Microsoft edge works well.  The second map style interacts more cleanly and reliably in Colab. Both types of maps are saved to files to give the viewer more options for utilizing the maps.

# %%
# %pip install pgeocode
# Out:
# Collecting pgeocode
#   Downloading pgeocode-0.5.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from pgeocode) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from pgeocode) (2.0.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from pgeocode) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas->pgeocode) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->pgeocode) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->pgeocode) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->pgeocode) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->pgeocode) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->pgeocode) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->pgeocode) (2026.5.20)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas->pgeocode) (1.17.0)
# Downloading pgeocode-0.5.0-py3-none-any.whl (9.8 kB)
# Installing collected packages: pgeocode
# Successfully installed pgeocode-0.5.0

# %%
import pgeocode

nomi = pgeocode.Nominatim('us')

# %% [markdown]
# Adding longitude and latitude to dataframes

# %% [markdown]
# ### Family Practice

# %%
# Batch lookup coordinates using the series
geo_data = nomi.query_postal_code(df_nmfam['zip_5'].tolist())
geo_data
# Out:
#      postal_code country_code   place_name  state_name state_code county_name  \
# 0          87102           US  Albuquerque  New Mexico         NM  Bernalillo
# 1          87110           US  Albuquerque  New Mexico         NM  Bernalillo
# 2          87110           US  Albuquerque  New Mexico         NM  Bernalillo
# 3          87110           US  Albuquerque  New Mexico         NM  Bernalillo
# 4          87110           US  Albuquerque  New Mexico         NM  Bernalillo
# ...          ...          ...          ...         ...        ...         ...
# 1151       87327           US         Zuni  New Mexico         NM    McKinley
# 1152       87327           US         Zuni  New Mexico         NM    McKinley
# 1153       87327           US         Zuni  New Mexico         NM    McKinley
# 1154       87327           US         Zuni  New Mexico         NM    McKinley
# 1155       87327           US         Zuni  New Mexico         NM    McKinley
#
#       county_code community_name  community_code  latitude  longitude  \
# 0             1.0           None             NaN   35.0818  -106.6482
# 1             1.0           None             NaN   35.1104  -106.5781
# 2             1.0           None             NaN   35.1104  -106.5781
# 3             1.0           None             NaN   35.1104  -106.5781
# 4             1.0           None             NaN   35.1104  -106.5781
# ...           ...            ...             ...       ...        ...
# 1151         31.0           None             NaN   35.0684  -108.8336
# 1152         31.0           None             NaN   35.0684  -108.8336
# 1153         31.0           None             NaN   35.0684  -108.8336
# 1154         31.0           None             NaN   35.0684  -108.8336
# 1155         31.0           None             NaN   35.0684  -108.8336
#
#       accuracy
# 0          4.0
# 1          4.0
# 2          4.0
# 3          4.0
# 4          4.0
# ...        ...
# 1151       4.0
# 1152       4.0
# 1153       4.0
# 1154       4.0
# 1155       4.0
#
# [1156 rows x 12 columns]

# %%
# Join coordinates and county names back to your dataframe
df_nmfam['latitude'] = geo_data['latitude'].values
df_nmfam['longitude'] = geo_data['longitude'].values
df_nmfam['county_name'] = geo_data['county_name'].values
# Out:
# /tmp/ipykernel_26849/151263499.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmfam['latitude'] = geo_data['latitude'].values
# /tmp/ipykernel_26849/151263499.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmfam['longitude'] = geo_data['longitude'].values
# /tmp/ipykernel_26849/151263499.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmfam['county_name'] = geo_data['county_name'].values

# %%
# Drop any rows that couldn't be resolved
df_nmfam = df_nmfam.dropna(subset=['latitude', 'longitude'])

print(f"Successfully geocoded {len(df_nmfam)} providers via ZIP code centroids!")
# Out:
# Successfully geocoded 1153 providers via ZIP code centroids!

# %%
import folium
from folium.plugins import MarkerCluster

# 1. Initialize map centered on New Mexico
nm_map = folium.Map(location=[34.5199, -105.8701], zoom_start=7)

# %%
# 3. Overlay the Cardiology Provider Markers using a Cluster layer for clean viewing
marker_cluster = MarkerCluster(name="Family Practice").add_to(nm_map)

for idx, row in df_nmfam.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='heart', prefix='fa')
    ).add_to(marker_cluster)

# 4. Add layer controls so you can toggle views on/off
folium.LayerControl().add_to(nm_map)

# Save or display the map
nm_map.save("nm_family_practice_risk_map.html")
nm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51b754fbb6ecce326c409bcf0edc0bb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51b754fbb6ecce326c409bcf0edc0bb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51b754fbb6ecce326c409bcf0edc0bb2 = L.map(
#                 &quot;map_51b754fbb6ecce326c409bcf0edc0bb2&quot;,
#                 {
#                     center: [34.5199, -105.8701],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4fffce579c7fea638b5a815b94d9f2aa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4fffce579c7fea638b5a815b94d9f2aa.addTo(map_51b754fbb6ecce326c409bcf0edc0bb2);
#
#
#             var marker_cluster_91a93062e72638fbecd5f1a17bcefc19 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_7dff62ee8ae74cbe00b720f4492685d2 = L.marker(
#                 [35.0818, -106.6482],
#                 {
# }
#             ).addTo(marker_cluster_91a93062e72638fbecd5f1a17bcefc19);
#
#
#             var icon_71a4d552ace5d73481b941075b0798f7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a0bd867bff422f1f1cbd0c782b8b9b99 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76c1696b02f48ed34dc09300170c45db = $(`&lt;div id=&quot;html_76c1696b02f48ed34dc09300170c45db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. RACHEL QUINN&lt;/div&gt;`)[0];
#                 popup_a0bd867bff422f1f1cbd0c782b8b9b99.setContent(html_76c1696b02f48ed34dc09300170c45db);
#
#
#
#         marker_7dff62ee8ae74cbe00b720f4492685d2.bindPopup(popup_a0bd867bff422f1f1cbd0c782b8b9b99)
#         ;
#
#
#
#
#                 marker_7dff62ee8ae74cbe00b720f4492685d2.setIcon(icon_71a4d552ace5d73481b941075b0798f7);
#
#
#             var marker_ec34c6236a06c9974210c7c594a39b89 = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_91a93062e72638fbecd5f1a17bcefc19);
#
#
#             var icon_89453bdc479d4af4f30d595b7a60fd16 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_8d47ad5516b444a1f47424a1bb783ad6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_94a206f7480be85aecbf9b567eedc3fd = $(`&lt;div id=&quot;html_94a206f7480be85aecbf9b567eedc3fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. LISA STOLARCZYK&lt;/div&gt;`)[0];
#                 popup_8d47ad5516b444a1f47424a1bb783ad6.setContent(html_94a206f7480be85aecbf9b567eedc3fd);
#
#
#
#         marker_ec34c6236a06c9974210c7c594a39b89.bindPopup(popup_8d47ad5516b444a1f47424a1bb783ad6)
#         ;
#
#
#
#
#                 marker_ec34c6236a06c9974210c7c594a39b89.setIcon(icon_89453bdc479d4af4f30d595b7a60fd16);
#
#
#             var marker_7d4fee562617b19d451558bc7cfd4196 = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_91a93062e72638fbecd5f1a17bcefc19);
#
#
#             var icon_f28569cba5ba0f2f610aef434aebfda7 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_4ca664f588a4364710acda96bc98b1b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78cb8303641b7621b138367e9

# %%
from folium.plugins import MarkerCluster
from IPython.display import HTML

# 1. Build the map using CartoDB tiles (doesn't trigger the OSM 403 block)
nm_map = folium.Map(location=[34.512, -105.988], zoom_start=7, tiles="CartoDB positron")
marker_cluster = MarkerCluster(name="Family Practice").add_to(nm_map)

# 2. Map your 60 rows
for idx, row in df_nmfam.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

folium.LayerControl().add_to(nm_map)

# 3. Save it locally
output_file = "nm_family_practice_risk_map2.html"
nm_map.save(output_file)

# 4. THE OFFLINE WORKAROUND: Read the raw text of the file and force-inject it
with open(output_file, 'r', encoding='utf-8') as f:
    html_content = f.read()

# Display it inside the notebook by passing the raw HTML text string
HTML(f'<div style="width:100%; height:1000px;">{html_content}</div>')
# Out:
# <div style="width:100%; height:1000px;"><!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_9283dab78eec3c17be2b256ef94622e1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#             <style>html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             </style>
#
#             <style>#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             </style>
#
#             <script>
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             </script>
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js"></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css"/>
# </head>
# <body>
#
#
#             <div class="folium-map" id="map_9283dab78eec3c17be2b256ef94622e1" ></div>
#
# </body>
# <script>
#
#
#             var map_9283dab78eec3c17be2b256ef94622e1 = L.map(
#                 "map_9283dab78eec3c17be2b256ef94622e1",
#                 {
#                     center: [34.512, -105.988],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   "zoom": 7,
#   "zoomControl": true,
#   "preferCanvas": false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c178d64df1463ad95a98ffac5dee8b9d = L.tileLayer(
#                 "https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
#                 {
#   "minZoom": 0,
#   "maxZoom": 20,
#   "maxNativeZoom": 20,
#   "noWrap": false,
#   "attribution": "\u0026copy; \u003ca href=\"https://www.openstreetmap.org/copyright\"\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\"https://carto.com/attributions\"\u003eCARTO\u003c/a\u003e",
#   "subdomains": "abcd",
#   "detectRetina": false,
#   "tms": false,
#   "opacity": 1,
# }
#
#             );
#
#
#             tile_layer_c178d64df1463ad95a98ffac5dee8b9d.addTo(map_9283dab78eec3c17be2b256ef94622e1);
#
#
#             var marker_cluster_f1452df62a0756f0e8d85d7f5c3d3f01 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_d019deffef8eaf1ff785f9826342d710 = L.marker(
#                 [35.0818, -106.6482],
#                 {
# }
#             ).addTo(marker_cluster_f1452df62a0756f0e8d85d7f5c3d3f01);
#
#
#             var icon_b0f804f7abf582f6488e78a20b4de3b5 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_bd39451b0e77590590a0dc2502b9288c = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_4f30c409f7c9b9161b6311519c128ca3 = $(`<div id="html_4f30c409f7c9b9161b6311519c128ca3" style="width: 100.0%; height: 100.0%;">Dr. RACHEL QUINN</div>`)[0];
#                 popup_bd39451b0e77590590a0dc2502b9288c.setContent(html_4f30c409f7c9b9161b6311519c128ca3);
#
#
#
#         marker_d019deffef8eaf1ff785f9826342d710.bindPopup(popup_bd39451b0e77590590a0dc2502b9288c)
#         ;
#
#
#
#
#                 marker_d019deffef8eaf1ff785f9826342d710.setIcon(icon_b0f804f7abf582f6488e78a20b4de3b5);
#
#
#             var marker_572b6d39b61827daa69f53eba93a1bc0 = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_f1452df62a0756f0e8d85d7f5c3d3f01);
#
#
#             var icon_31001b7f96cba15b0f2b2dcda689585d = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_59b6c289ea3f7bfb92de5aac92c1d7b5 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_a92e20d72699960b241a5e0733f34904 = $(`<div id="html_a92e20d72699960b241a5e0733f34904" style="width: 100.0%; height: 100.0%;">Dr. LISA STOLARCZYK</div>`)[0];
#                 popup_59b6c289ea3f7bfb92de5aac92c1d7b5.setContent(html_a92e20d72699960b241a5e0733f34904);
#
#
#
#         marker_572b6d39b61827daa69f53eba93a1bc0.bindPopup(popup_59b6c289ea3f7bfb92de5aac92c1d7b5)
#         ;
#
#
#
#
#                 marker_572b6d39b61827daa69f53eba93a1bc0.setIcon(icon_31001b7f96cba15b0f2b2dcda689585d);
#
#
#             var marker_8dd21feb825df2a17938e7c72a4ee4f4 = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_f1452df62a0756f0e8d85d7f5c3d3f01);
#
#
#             var icon_f040cc7b087ddbbee0c4371110aa83ff = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_3ab78a120eacfe773b541391fa9628f4 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_3857728b916a4ee27a94362ea2138ed2 = $(`<div id="html_3857728b916a4ee27a94362ea2138ed2" style="width: 100.0%; height: 100.0%;">Dr. FARES YASIN</div>`)[0];
#                 popup_3ab78a120eacfe773b541391fa9628f4.setContent(html_3857728b916a4ee27a94362ea2138ed2);
#
#
#
#         marker_8dd21feb825df2a17938e7c72a4ee4f4.bindPopup(popup_3ab78a120eacfe773b541391fa9628f4)
#         ;
#
#
#
#
#                 marker_8dd21feb825df2a17938e7c72a4ee4f4.setIcon(icon_f040cc7b087ddbbee0c4371110aa83ff);
#
#
#             var marker_88a123411b107522c771ec7359e6012b = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_f1452df62a0756f0e8d85d7f5c3d3f01);
#
#
#             var icon_09a41c070323809104dc63a10442fc61 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_523f174ffa786374f2201f6414cdef8b = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_3db95c762e

# %% [markdown]
# ### Geriatric Medicine

# %%
# Batch lookup coordinates using the series
geo_data2 = nomi.query_postal_code(df_nmger['zip_5'].tolist())
geo_data2
# Out:
#    postal_code country_code             place_name  state_name state_code  \
# 0        87110           US            Albuquerque  New Mexico         NM
# 1        87532           US               Espanola  New Mexico         NM
# 2        87020           US                 Grants  New Mexico         NM
# 3        88011           US             Las Cruces  New Mexico         NM
# 4        88030           US                 Deming  New Mexico         NM
# 5        88061           US            Silver City  New Mexico         NM
# 6        87124           US             Rio Rancho  New Mexico         NM
# 7        87301           US                 Gallup  New Mexico         NM
# 8        87301           US                 Gallup  New Mexico         NM
# 9        88101           US                 Clovis  New Mexico         NM
# 10       88101           US                 Clovis  New Mexico         NM
# 11       87106           US            Albuquerque  New Mexico         NM
# 12       87106           US            Albuquerque  New Mexico         NM
# 13       87106           US            Albuquerque  New Mexico         NM
# 14       87106           US            Albuquerque  New Mexico         NM
# 15       87106           US            Albuquerque  New Mexico         NM
# 16       87106           US            Albuquerque  New Mexico         NM
# 17       87106           US            Albuquerque  New Mexico         NM
# 18       87112           US            Albuquerque  New Mexico         NM
# 19       87124           US             Rio Rancho  New Mexico         NM
# 20       87144           US             Rio Rancho  New Mexico         NM
# 21       87124           US             Rio Rancho  New Mexico         NM
# 22       88130           US               Portales  New Mexico         NM
# 23       87109           US            Albuquerque  New Mexico         NM
# 24       87048           US               Corrales  New Mexico         NM
# 25       87505           US               Santa Fe  New Mexico         NM
# 26       87505           US               Santa Fe  New Mexico         NM
# 27       87114           US            Albuquerque  New Mexico         NM
# 28       87111           US            Albuquerque  New Mexico         NM
# 29       87505           US               Santa Fe  New Mexico         NM
# 30       87505           US               Santa Fe  New Mexico         NM
# 31       87505           US               Santa Fe  New Mexico         NM
# 32       87109           US            Albuquerque  New Mexico         NM
# 33       87108           US            Albuquerque  New Mexico         NM
# 34       87102           US            Albuquerque  New Mexico         NM
# 35       87401           US             Farmington  New Mexico         NM
# 36       87109           US            Albuquerque  New Mexico         NM
# 37       87102           US            Albuquerque  New Mexico         NM
# 38       87901           US  Truth Or Consequences  New Mexico         NM
# 39       87110           US            Albuquerque  New Mexico         NM
# 40       87111           US            Albuquerque  New Mexico         NM
# 41       88030           US                 Deming  New Mexico         NM
# 42       87901           US  Truth Or Consequences  New Mexico         NM
#
#    county_name  county_code community_name  community_code  latitude  \
# 0   Bernalillo          1.0           None             NaN   35.1104
# 1   Rio Arriba         39.0           None             NaN   35.9872
# 2       Cibola          6.0           None             NaN   35.1476
# 3     Doña Ana         13.0           None             NaN   32.3244
# 4         Luna         29.0           None             NaN   32.2318
# 5        Grant         17.0           None             NaN   32.7900
# 6     Sandoval         43.0           None             NaN   35.2493
# 7     McKinley         31.0           None             NaN   35.5065
# 8     McKinley         31.0           None             NaN   35.5065
# 9        Curry          9.0           None             NaN   34.4126
# 10       Curry          9.0           None             NaN   34.4126
# 11  Bernalillo          1.0           None             NaN   35.0790
# 12  Bernalillo          1.0           None             NaN   35.0790
# 13  Bernalillo          1.0           None             NaN   35.0790
# 14  Bernalillo          1.0           None             NaN   35.0790
# 15  Bernalillo          1.0           None             NaN   35.0790
# 16  Bernalillo          1.0           None             NaN   35.0790
# 17  Bernalillo          1.0           None             NaN   35.0790
# 18  Bernalillo          1.0           None             NaN   35.1010
# 19    Sandoval         43.0           None             NaN   35.2493
# 20    Sandoval         43.0           None             NaN   35.3240
# 21    Sandoval         43.0           None             NaN   35.2493
# 22   Roosevelt         41.0           None             NaN   34.1799
# 23  Bernalillo          1.0           None             NaN   35.1506
# 24    Sandoval         43.0           None             NaN   35.2339
# 25    Santa Fe         49.0           None             NaN   35.6219
# 26    Santa Fe         49.0           None             NaN   35.6219
# 27  Bernalillo          1.0           None             NaN   35.1868
# 28  Bernalillo          1.0           None             NaN   35.1347
# 29    Santa Fe         49.0           None             NaN   35.6219
# 30    Santa Fe         49.0           None             NaN   35.6219
# 31    Santa Fe         49.0           None             NaN   35.6219
# 32  Bernalillo          1.0           None             NaN   35.1506
# 33  Bernalillo          1.0           None             NaN   35.0726
# 34  Bernalillo          1.0           None             NaN   35.0818
# 35    San Juan         45.0           None             NaN   36.7412
# 36  Bernalillo          1.0           None             NaN   35.1506
# 37  Bernalillo          1.0           None             NaN   35.0818
# 38      Sierra         51.0           None             NaN   33.1606
# 39  Bernalillo          1.0           None             NaN   35.1104
# 40  Bernalillo          1.0           None             NaN   35.1347
# 41        Luna         29.0           None             NaN   32.2318
# 42      Sierra         51.0           None             NaN   33.1606
#
#     longitude  accuracy
# 0   -106.5781       4.0
# 1   -106.0717       4.0
# 2   -107.8526       4.0
# 3   -106.6683       4.0
# 4   -107.7466       4.0
# 5   -108.2749       4.0
# 6   -106.6818       4.0
# 7   -108.7414       4.0
# 8   -108.7414       4.0
# 9   -103.2214       4.0
# 10  -103.2214       4.0
# 11  -106.6169       4.0
# 12  -106.6169       4.0
# 13  -106.6169       4.0
# 14  -106.6169       4.0
# 15  -106.6169       4.0
# 16  -106.6169       4.0
# 17  -106.6169       4.0
# 18  -106.5183       4.0
# 19  -106.6818       4.0
# 20  -106.7099       4.0
# 21  -106.6818       4.0
# 22  -103.3363       4.0
# 23  -106.5690       4.0
# 24  -106.6200       4.0
# 25  -105.8688       4.0
# 26  -105.8688       4.0
# 27  -106.6652       4.0
# 28  -106.5222       4.0
# 29  -105.8688       4.0
# 30  -105.8688       4.0
# 31  -105.8688       4.0
# 32  -106.5690       4.0
# 33  -106.5749       4.0
# 34  -106.6482       4.0
# 35  -108.1797       4.0
# 36  -106.5690       4.0
# 37  -106.6482       4.0
# 38  -107.2669       4.0
# 39  -106.5781       4.0
# 40  -106.5222       4.0
# 41  -107.7466       4.0
# 42  -107.2669       4.0

# %%
# Join coordinates and county names back to your dataframe
df_nmger['latitude'] = geo_data2['latitude'].values
df_nmger['longitude'] = geo_data2['longitude'].values
df_nmger['county_name'] = geo_data2['county_name'].values
# Out:
# /tmp/ipykernel_26849/2105746643.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmger['latitude'] = geo_data2['latitude'].values
# /tmp/ipykernel_26849/2105746643.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmger['longitude'] = geo_data2['longitude'].values
# /tmp/ipykernel_26849/2105746643.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmger['county_name'] = geo_data2['county_name'].values

# %%
# Drop any rows that couldn't be resolved
df_nmger = df_nmger.dropna(subset=['latitude', 'longitude'])

print(f"Successfully geocoded {len(df_nmger)} providers via ZIP code centroids!")
# Out:
# Successfully geocoded 43 providers via ZIP code centroids!

# %%
from folium.plugins import MarkerCluster
from IPython.display import IFrame

# 1. Initialize map centered on New Mexico
nm_map = folium.Map(location=[34.5199, -105.8701], zoom_start=7)

# %%
# 3. Overlay the Cardiology Provider Markers using a Cluster layer for clean viewing
marker_cluster = MarkerCluster(name="Geritric Medicine").add_to(nm_map)

for idx, row in df_nmger.iterrows():
  popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

  folium.Marker(
    location=[row['latitude'], row['longitude']],
    popup=popup_text,
    icon=folium.Icon(color='blue', icon='heart', prefix='fa')
  ).add_to(marker_cluster)

# 4. Add layer controls so you can toggle views on/off
folium.LayerControl().add_to(nm_map)

# Save or display the map
nm_map.save("nm_geriatric_medicine_risk_map.html")
nm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_bad696d8a1385ac4e641cc9cb1d97c0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_bad696d8a1385ac4e641cc9cb1d97c0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_bad696d8a1385ac4e641cc9cb1d97c0f = L.map(
#                 &quot;map_bad696d8a1385ac4e641cc9cb1d97c0f&quot;,
#                 {
#                     center: [34.5199, -105.8701],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_22e2a11f7262b3b62df5187ac50673f4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_22e2a11f7262b3b62df5187ac50673f4.addTo(map_bad696d8a1385ac4e641cc9cb1d97c0f);
#
#
#             var marker_cluster_5da584a4688b0e0a2bfe82dc3b58b137 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_982aa90bd9ad8f2089f92222295056fa = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_5da584a4688b0e0a2bfe82dc3b58b137);
#
#
#             var icon_1180f69fa99143ec3e87d87e5f74f9fd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_afbba80e4281129c30c582f75866bc82 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b70125b56a8323df118e25b3ddfb972a = $(`&lt;div id=&quot;html_b70125b56a8323df118e25b3ddfb972a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. JILL RHYMES&lt;/div&gt;`)[0];
#                 popup_afbba80e4281129c30c582f75866bc82.setContent(html_b70125b56a8323df118e25b3ddfb972a);
#
#
#
#         marker_982aa90bd9ad8f2089f92222295056fa.bindPopup(popup_afbba80e4281129c30c582f75866bc82)
#         ;
#
#
#
#
#                 marker_982aa90bd9ad8f2089f92222295056fa.setIcon(icon_1180f69fa99143ec3e87d87e5f74f9fd);
#
#
#             var marker_4ebf59265e7d5d1ef472541f459c5872 = L.marker(
#                 [35.9872, -106.0717],
#                 {
# }
#             ).addTo(marker_cluster_5da584a4688b0e0a2bfe82dc3b58b137);
#
#
#             var icon_6ece89495840f3e2691bf0058e27dae8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_65f84b6577e28b366a0953612dac6a3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13dff5b07a3a40d991464ced28594c51 = $(`&lt;div id=&quot;html_13dff5b07a3a40d991464ced28594c51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. GEORGINA LEAMON&lt;/div&gt;`)[0];
#                 popup_65f84b6577e28b366a0953612dac6a3b.setContent(html_13dff5b07a3a40d991464ced28594c51);
#
#
#
#         marker_4ebf59265e7d5d1ef472541f459c5872.bindPopup(popup_65f84b6577e28b366a0953612dac6a3b)
#         ;
#
#
#
#
#                 marker_4ebf59265e7d5d1ef472541f459c5872.setIcon(icon_6ece89495840f3e2691bf0058e27dae8);
#
#
#             var marker_53b748fc46cd7dd57e0c9081b1f0a137 = L.marker(
#                 [35.1476, -107.8526],
#                 {
# }
#             ).addTo(marker_cluster_5da584a4688b0e0a2bfe82dc3b58b137);
#
#
#             var icon_67e4c8920bf63c06a47a201f5f20e8fd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2d058f7d4fbff8a47c19a79ad884254f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b924edc3810956a3e67a2ad87

# %%
from folium.plugins import MarkerCluster
from IPython.display import HTML

# 1. Build the map using CartoDB tiles (doesn't trigger the OSM 403 block)
nm_map = folium.Map(location=[34.512, -105.988], zoom_start=7, tiles="CartoDB positron")
marker_cluster = MarkerCluster(name="Geriatric Medicine").add_to(nm_map)

# 2. Map your 60 rows
for idx, row in df_nmger.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

folium.LayerControl().add_to(nm_map)

# 3. Save it locally
output_file = "nm_geriatric_medicine_risk_map2.html"
nm_map.save(output_file)

# 4. THE OFFLINE WORKAROUND: Read the raw text of the file and force-inject it
with open(output_file, 'r', encoding='utf-8') as f:
    html_content = f.read()

# Display it inside the notebook by passing the raw HTML text string
HTML(f'<div style="width:100%; height:1000px;">{html_content}</div>')
# Out:
# <div style="width:100%; height:1000px;"><!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_c3dacad0c62994c43aa6dbfe7ae35986 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#             <style>html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             </style>
#
#             <style>#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             </style>
#
#             <script>
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             </script>
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js"></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css"/>
# </head>
# <body>
#
#
#             <div class="folium-map" id="map_c3dacad0c62994c43aa6dbfe7ae35986" ></div>
#
# </body>
# <script>
#
#
#             var map_c3dacad0c62994c43aa6dbfe7ae35986 = L.map(
#                 "map_c3dacad0c62994c43aa6dbfe7ae35986",
#                 {
#                     center: [34.512, -105.988],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   "zoom": 7,
#   "zoomControl": true,
#   "preferCanvas": false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_82441d08fb80825a56a40bc07660e799 = L.tileLayer(
#                 "https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
#                 {
#   "minZoom": 0,
#   "maxZoom": 20,
#   "maxNativeZoom": 20,
#   "noWrap": false,
#   "attribution": "\u0026copy; \u003ca href=\"https://www.openstreetmap.org/copyright\"\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\"https://carto.com/attributions\"\u003eCARTO\u003c/a\u003e",
#   "subdomains": "abcd",
#   "detectRetina": false,
#   "tms": false,
#   "opacity": 1,
# }
#
#             );
#
#
#             tile_layer_82441d08fb80825a56a40bc07660e799.addTo(map_c3dacad0c62994c43aa6dbfe7ae35986);
#
#
#             var marker_cluster_6d9c51553fb2dec84d9c0a599bc567d8 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_61b52480c233a41a020be0306464d1d6 = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_6d9c51553fb2dec84d9c0a599bc567d8);
#
#
#             var icon_cef1e63b5c7f5b1e1e76faa6af3a8072 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_608cb2aca8a931906c4a54ea93a3b78c = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_be2850bbe41221abb7973f79a956a575 = $(`<div id="html_be2850bbe41221abb7973f79a956a575" style="width: 100.0%; height: 100.0%;">Dr. JILL RHYMES</div>`)[0];
#                 popup_608cb2aca8a931906c4a54ea93a3b78c.setContent(html_be2850bbe41221abb7973f79a956a575);
#
#
#
#         marker_61b52480c233a41a020be0306464d1d6.bindPopup(popup_608cb2aca8a931906c4a54ea93a3b78c)
#         ;
#
#
#
#
#                 marker_61b52480c233a41a020be0306464d1d6.setIcon(icon_cef1e63b5c7f5b1e1e76faa6af3a8072);
#
#
#             var marker_f849c4bc64d952d752755b452be55f13 = L.marker(
#                 [35.9872, -106.0717],
#                 {
# }
#             ).addTo(marker_cluster_6d9c51553fb2dec84d9c0a599bc567d8);
#
#
#             var icon_49c3af20164c5ec421cee81b3c91c2fc = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_be1ff2113336d8a1c82621e452b493e2 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_46225b931edb52e3514c415a1e2ef012 = $(`<div id="html_46225b931edb52e3514c415a1e2ef012" style="width: 100.0%; height: 100.0%;">Dr. GEORGINA LEAMON</div>`)[0];
#                 popup_be1ff2113336d8a1c82621e452b493e2.setContent(html_46225b931edb52e3514c415a1e2ef012);
#
#
#
#         marker_f849c4bc64d952d752755b452be55f13.bindPopup(popup_be1ff2113336d8a1c82621e452b493e2)
#         ;
#
#
#
#
#                 marker_f849c4bc64d952d752755b452be55f13.setIcon(icon_49c3af20164c5ec421cee81b3c91c2fc);
#
#
#             var marker_58819ee377c95e62a02f26b748c982a0 = L.marker(
#                 [35.1476, -107.8526],
#                 {
# }
#             ).addTo(marker_cluster_6d9c51553fb2dec84d9c0a599bc567d8);
#
#
#             var icon_28ad849f4b0b814cf862e9eb0be301d3 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_9cd9c9fdcb5c87678785447501c117b5 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_a663ba37d704a6f980a71ebe7957a60c = $(`<div id="html_a663ba37d704a6f980a71ebe7957a60c" style="width: 100.0%; height: 100.0%;">Dr. JOSEPH FEAGAN</div>`)[0];
#                 popup_9cd9c9fdcb5c87678785447501c117b5.setContent(html_a663ba37d704a6f980a71ebe7957a60c);
#
#
#
#         marker_58819ee377c95e62a02f26b748c982a0.bindPopup(popup_9cd9c9fdcb5c87678785447501c117b5)
#         ;
#
#
#
#
#                 marker_58819ee377c95e62a02f26b748c982a0.setIcon(icon_28ad849f4b0b814cf862e9eb0be301d3);
#
#
#             var marker_5f1755f28213144b78a00e420e885c30 = L.marker(
#                 [32.3244, -106.6683],
#                 {
# }
#             ).addTo(marker_cluster_6d9c51553fb2dec84d9c0a599bc567d8);
#
#
#             var icon_ffb41d652adc20c9c026ff6380139d17 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_5741262deaf600f29859670136a75af8 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_26962c227

# %% [markdown]
# ### Cardiology

# %%
# Batch lookup coordinates using the series
geo_data = nomi.query_postal_code(df_nmcard['zip_5'].tolist())
geo_data
# Out:
#     postal_code country_code   place_name  state_name state_code county_name  \
# 0         87505           US     Santa Fe  New Mexico         NM    Santa Fe
# 1         87505           US     Santa Fe  New Mexico         NM    Santa Fe
# 2         87532           US     Espanola  New Mexico         NM  Rio Arriba
# 3         87532           US     Espanola  New Mexico         NM  Rio Arriba
# 4         87020           US       Grants  New Mexico         NM      Cibola
# ..          ...          ...          ...         ...        ...         ...
# 211       88030           US       Deming  New Mexico         NM        Luna
# 212       87125           US  Albuquerque  New Mexico         NM  Bernalillo
# 213       87125           US  Albuquerque  New Mexico         NM  Bernalillo
# 214       87125           US  Albuquerque  New Mexico         NM  Bernalillo
# 215       87125           US  Albuquerque  New Mexico         NM  Bernalillo
#
#      county_code community_name  community_code  latitude  longitude  accuracy
# 0           49.0           None             NaN   35.6219  -105.8688       4.0
# 1           49.0           None             NaN   35.6219  -105.8688       4.0
# 2           39.0           None             NaN   35.9872  -106.0717       4.0
# 3           39.0           None             NaN   35.9872  -106.0717       4.0
# 4            6.0           None             NaN   35.1476  -107.8526       4.0
# ..           ...            ...             ...       ...        ...       ...
# 211         29.0           None             NaN   32.2318  -107.7466       4.0
# 212          1.0           None             NaN   35.0443  -106.6729       4.0
# 213          1.0           None             NaN   35.0443  -106.6729       4.0
# 214          1.0           None             NaN   35.0443  -106.6729       4.0
# 215          1.0           None             NaN   35.0443  -106.6729       4.0
#
# [216 rows x 12 columns]

# %%
# Join coordinates and county names back to your dataframe
df_nmcard['latitude'] = geo_data['latitude'].values
df_nmcard['longitude'] = geo_data['longitude'].values
df_nmcard['county_name'] = geo_data['county_name'].values
# Out:
# /tmp/ipykernel_26849/3380993935.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmcard['latitude'] = geo_data['latitude'].values
# /tmp/ipykernel_26849/3380993935.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmcard['longitude'] = geo_data['longitude'].values
# /tmp/ipykernel_26849/3380993935.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmcard['county_name'] = geo_data['county_name'].values

# %%
# Drop any rows that couldn't be resolved
df_nmcard = df_nmcard.dropna(subset=['latitude', 'longitude'])

print(f"Successfully geocoded {len(df_nmcard)} providers via ZIP code centroids!")
# Out:
# Successfully geocoded 216 providers via ZIP code centroids!

# %%
from folium.plugins import MarkerCluster

# 1. Initialize map centered on New Mexico
nm_map = folium.Map(location=[34.5199, -105.8701], zoom_start=7)

# %%
# 3. Overlay the Cardiology Provider Markers using a Cluster layer for clean viewing
marker_cluster = MarkerCluster(name="Cardiology").add_to(nm_map)

for idx, row in df_nmcard.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='heart', prefix='fa')
    ).add_to(marker_cluster)

# 4. Add layer controls so you can toggle views on/off
folium.LayerControl().add_to(nm_map)

# Save or display the map
nm_map.save("nm_cardiology_risk_map.html")
nm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_eb6679227ae6b97d3d4178c355f340a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_eb6679227ae6b97d3d4178c355f340a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_eb6679227ae6b97d3d4178c355f340a5 = L.map(
#                 &quot;map_eb6679227ae6b97d3d4178c355f340a5&quot;,
#                 {
#                     center: [34.5199, -105.8701],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_982d0a7c6f4b2da9b3c95189c92f1917 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_982d0a7c6f4b2da9b3c95189c92f1917.addTo(map_eb6679227ae6b97d3d4178c355f340a5);
#
#
#             var marker_cluster_0ba76ce216693149f78bfea34b8cdcc1 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_4b9dbccc4049a94c0a32d35fc2178402 = L.marker(
#                 [35.6219, -105.8688],
#                 {
# }
#             ).addTo(marker_cluster_0ba76ce216693149f78bfea34b8cdcc1);
#
#
#             var icon_50db4e64657a23e2a36bc2a9f101b721 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_359b1041b11743a42a4def790438493a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5099ddae5200cf1f02506d5ba38e409 = $(`&lt;div id=&quot;html_e5099ddae5200cf1f02506d5ba38e409&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. DENNIS INCORVATI&lt;/div&gt;`)[0];
#                 popup_359b1041b11743a42a4def790438493a.setContent(html_e5099ddae5200cf1f02506d5ba38e409);
#
#
#
#         marker_4b9dbccc4049a94c0a32d35fc2178402.bindPopup(popup_359b1041b11743a42a4def790438493a)
#         ;
#
#
#
#
#                 marker_4b9dbccc4049a94c0a32d35fc2178402.setIcon(icon_50db4e64657a23e2a36bc2a9f101b721);
#
#
#             var marker_e4e0b3b43c9146625636cec5e287480b = L.marker(
#                 [35.6219, -105.8688],
#                 {
# }
#             ).addTo(marker_cluster_0ba76ce216693149f78bfea34b8cdcc1);
#
#
#             var icon_526454a894013b6e84b1b55f66a5ecfe = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9e63b75e56aa156997102d8cc26ce716 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be0f99e3360237554b17c29a29ba020c = $(`&lt;div id=&quot;html_be0f99e3360237554b17c29a29ba020c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. KETAN GALA&lt;/div&gt;`)[0];
#                 popup_9e63b75e56aa156997102d8cc26ce716.setContent(html_be0f99e3360237554b17c29a29ba020c);
#
#
#
#         marker_e4e0b3b43c9146625636cec5e287480b.bindPopup(popup_9e63b75e56aa156997102d8cc26ce716)
#         ;
#
#
#
#
#                 marker_e4e0b3b43c9146625636cec5e287480b.setIcon(icon_526454a894013b6e84b1b55f66a5ecfe);
#
#
#             var marker_2e44a25f3d2b9d63ae15ae9ee8daf1e7 = L.marker(
#                 [35.9872, -106.0717],
#                 {
# }
#             ).addTo(marker_cluster_0ba76ce216693149f78bfea34b8cdcc1);
#
#
#             var icon_7cd1ce3680384b60b27880cd08ea9a3e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_9e26a1d9820fa0b4daa4248499092853 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a7d07479800efe6805f2b8994

# %%
from folium.plugins import MarkerCluster
from IPython.display import HTML

# 1. Build the map using CartoDB tiles (doesn't trigger the OSM 403 block)
nm_map = folium.Map(location=[34.512, -105.988], zoom_start=7, tiles="CartoDB positron")
marker_cluster = MarkerCluster(name="Cardiology").add_to(nm_map)

# 2. Map your 60 rows
for idx, row in df_nmcard.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

folium.LayerControl().add_to(nm_map)

# 3. Save it locally
output_file = "nm_cardiology_risk_map2.html"
nm_map.save(output_file)

# 4. THE OFFLINE WORKAROUND: Read the raw text of the file and force-inject it
with open(output_file, 'r', encoding='utf-8') as f:
    html_content = f.read()

# Display it inside the notebook by passing the raw HTML text string
HTML(f'<div style="width:100%; height:1000px;">{html_content}</div>')
# Out:
# <div style="width:100%; height:1000px;"><!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_2354b9dcbbcdbe56622b1da6192da891 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#             <style>html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             </style>
#
#             <style>#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             </style>
#
#             <script>
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             </script>
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js"></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css"/>
# </head>
# <body>
#
#
#             <div class="folium-map" id="map_2354b9dcbbcdbe56622b1da6192da891" ></div>
#
# </body>
# <script>
#
#
#             var map_2354b9dcbbcdbe56622b1da6192da891 = L.map(
#                 "map_2354b9dcbbcdbe56622b1da6192da891",
#                 {
#                     center: [34.512, -105.988],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   "zoom": 7,
#   "zoomControl": true,
#   "preferCanvas": false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2d7576ce9bae492260189fe54f8c4e5f = L.tileLayer(
#                 "https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
#                 {
#   "minZoom": 0,
#   "maxZoom": 20,
#   "maxNativeZoom": 20,
#   "noWrap": false,
#   "attribution": "\u0026copy; \u003ca href=\"https://www.openstreetmap.org/copyright\"\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\"https://carto.com/attributions\"\u003eCARTO\u003c/a\u003e",
#   "subdomains": "abcd",
#   "detectRetina": false,
#   "tms": false,
#   "opacity": 1,
# }
#
#             );
#
#
#             tile_layer_2d7576ce9bae492260189fe54f8c4e5f.addTo(map_2354b9dcbbcdbe56622b1da6192da891);
#
#
#             var marker_cluster_417fddadb7228f211a13fa1838b2aaa5 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_e7b8520b9ef95fd5a88e928a62cbfa30 = L.marker(
#                 [35.6219, -105.8688],
#                 {
# }
#             ).addTo(marker_cluster_417fddadb7228f211a13fa1838b2aaa5);
#
#
#             var icon_7bd8ece15684f2f7d3a71bb83b426374 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_ab842d17c366a9a2824c35269df4e3fe = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_07c9990204bd554b6ee9de5c080c5a35 = $(`<div id="html_07c9990204bd554b6ee9de5c080c5a35" style="width: 100.0%; height: 100.0%;">Dr. DENNIS INCORVATI</div>`)[0];
#                 popup_ab842d17c366a9a2824c35269df4e3fe.setContent(html_07c9990204bd554b6ee9de5c080c5a35);
#
#
#
#         marker_e7b8520b9ef95fd5a88e928a62cbfa30.bindPopup(popup_ab842d17c366a9a2824c35269df4e3fe)
#         ;
#
#
#
#
#                 marker_e7b8520b9ef95fd5a88e928a62cbfa30.setIcon(icon_7bd8ece15684f2f7d3a71bb83b426374);
#
#
#             var marker_0c7476c7510d449b1a36ff54165ebc88 = L.marker(
#                 [35.6219, -105.8688],
#                 {
# }
#             ).addTo(marker_cluster_417fddadb7228f211a13fa1838b2aaa5);
#
#
#             var icon_5e89d7106820533f5c5467ec59fa874b = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_9c210999c004699604e2b83f2adcdf5f = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_8a433dcd77422bfb3841bc7d787e8d59 = $(`<div id="html_8a433dcd77422bfb3841bc7d787e8d59" style="width: 100.0%; height: 100.0%;">Dr. KETAN GALA</div>`)[0];
#                 popup_9c210999c004699604e2b83f2adcdf5f.setContent(html_8a433dcd77422bfb3841bc7d787e8d59);
#
#
#
#         marker_0c7476c7510d449b1a36ff54165ebc88.bindPopup(popup_9c210999c004699604e2b83f2adcdf5f)
#         ;
#
#
#
#
#                 marker_0c7476c7510d449b1a36ff54165ebc88.setIcon(icon_5e89d7106820533f5c5467ec59fa874b);
#
#
#             var marker_1f4d939bbeba087525aa85e04c388e11 = L.marker(
#                 [35.9872, -106.0717],
#                 {
# }
#             ).addTo(marker_cluster_417fddadb7228f211a13fa1838b2aaa5);
#
#
#             var icon_1091ed410a09898cbcb9bacabc4562a3 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_1af19450a9df12fecf1235b67007af8b = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_0e9bc1f3ede076374d3005535a8e9bf8 = $(`<div id="html_0e9bc1f3ede076374d3005535a8e9bf8" style="width: 100.0%; height: 100.0%;">Dr. AAMER REHMAN</div>`)[0];
#                 popup_1af19450a9df12fecf1235b67007af8b.setContent(html_0e9bc1f3ede076374d3005535a8e9bf8);
#
#
#
#         marker_1f4d939bbeba087525aa85e04c388e11.bindPopup(popup_1af19450a9df12fecf1235b67007af8b)
#         ;
#
#
#
#
#                 marker_1f4d939bbeba087525aa85e04c388e11.setIcon(icon_1091ed410a09898cbcb9bacabc4562a3);
#
#
#             var marker_2ca481c7f6549b164e7b58eda2e53c8b = L.marker(
#                 [35.9872, -106.0717],
#                 {
# }
#             ).addTo(marker_cluster_417fddadb7228f211a13fa1838b2aaa5);
#
#
#             var icon_ec4b7d976738361410646ba08e32bdcf = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_bfcb1e52e896728fd4531b96ead1a4a8 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_c17d9db8c5

# %% [markdown]
# ### Nephrology

# %%
# Batch lookup coordinates using the series
geo_data = nomi.query_postal_code(df_nmneph['zip_5'].tolist())
geo_data
# Out:
#    postal_code country_code   place_name  state_name state_code county_name  \
# 0        87110           US  Albuquerque  New Mexico         NM  Bernalillo
# 1        87106           US  Albuquerque  New Mexico         NM  Bernalillo
# 2        87301           US       Gallup  New Mexico         NM    McKinley
# 3        87301           US       Gallup  New Mexico         NM    McKinley
# 4        87301           US       Gallup  New Mexico         NM    McKinley
# ..         ...          ...          ...         ...        ...         ...
# 90       87420           US     Shiprock  New Mexico         NM    San Juan
# 91       87420           US     Shiprock  New Mexico         NM    San Juan
# 92       87420           US     Shiprock  New Mexico         NM    San Juan
# 93       87420           US     Shiprock  New Mexico         NM    San Juan
# 94       87420           US     Shiprock  New Mexico         NM    San Juan
#
#     county_code community_name  community_code  latitude  longitude  accuracy
# 0           1.0           None             NaN   35.1104  -106.5781       4.0
# 1           1.0           None             NaN   35.0790  -106.6169       4.0
# 2          31.0           None             NaN   35.5065  -108.7414       4.0
# 3          31.0           None             NaN   35.5065  -108.7414       4.0
# 4          31.0           None             NaN   35.5065  -108.7414       4.0
# ..          ...            ...             ...       ...        ...       ...
# 90         45.0           None             NaN   36.6560  -108.7355       4.0
# 91         45.0           None             NaN   36.6560  -108.7355       4.0
# 92         45.0           None             NaN   36.6560  -108.7355       4.0
# 93         45.0           None             NaN   36.6560  -108.7355       4.0
# 94         45.0           None             NaN   36.6560  -108.7355       4.0
#
# [95 rows x 12 columns]

# %%
# Join coordinates and county names back to your dataframe
df_nmneph['latitude'] = geo_data['latitude'].values
df_nmneph['longitude'] = geo_data['longitude'].values
df_nmneph['county_name'] = geo_data['county_name'].values
# Out:
# /tmp/ipykernel_26849/1079560451.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmneph['latitude'] = geo_data['latitude'].values
# /tmp/ipykernel_26849/1079560451.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmneph['longitude'] = geo_data['longitude'].values
# /tmp/ipykernel_26849/1079560451.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmneph['county_name'] = geo_data['county_name'].values

# %%
# Drop any rows that couldn't be resolved
df_nmneph = df_nmneph.dropna(subset=['latitude', 'longitude'])

print(f"Successfully geocoded {len(df_nmneph)} providers via ZIP code centroids!")
# Out:
# Successfully geocoded 95 providers via ZIP code centroids!

# %%
from folium.plugins import MarkerCluster

# 1. Initialize map centered on New Mexico
nm_map = folium.Map(location=[34.5199, -105.8701], zoom_start=7)

# %%
# 3. Overlay the Cardiology Provider Markers using a Cluster layer for clean viewing
marker_cluster = MarkerCluster(name="Nephrology").add_to(nm_map)

for idx, row in df_nmneph.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='heart', prefix='fa')
    ).add_to(marker_cluster)

# 4. Add layer controls so you can toggle views on/off
folium.LayerControl().add_to(nm_map)

# Save or display the map
nm_map.save("nm_nephrology_risk_map.html")
nm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_95adf80d1cdaec8b365dc5705783aadc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_95adf80d1cdaec8b365dc5705783aadc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_95adf80d1cdaec8b365dc5705783aadc = L.map(
#                 &quot;map_95adf80d1cdaec8b365dc5705783aadc&quot;,
#                 {
#                     center: [34.5199, -105.8701],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_eb6f18985b9850b7068414a7b32fda4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_eb6f18985b9850b7068414a7b32fda4a.addTo(map_95adf80d1cdaec8b365dc5705783aadc);
#
#
#             var marker_cluster_204e1b130447a06d1e7044e02075247e = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_bc4015ee77add4e92c85409bfb4c41a1 = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_204e1b130447a06d1e7044e02075247e);
#
#
#             var icon_2171b65cde4c29d307798507e93f268f = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_b4844cb05fd34589972f79dcede64be8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce98f4c64167214246f02c9416e7b84c = $(`&lt;div id=&quot;html_ce98f4c64167214246f02c9416e7b84c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. MAYBIN SIMFUKWE&lt;/div&gt;`)[0];
#                 popup_b4844cb05fd34589972f79dcede64be8.setContent(html_ce98f4c64167214246f02c9416e7b84c);
#
#
#
#         marker_bc4015ee77add4e92c85409bfb4c41a1.bindPopup(popup_b4844cb05fd34589972f79dcede64be8)
#         ;
#
#
#
#
#                 marker_bc4015ee77add4e92c85409bfb4c41a1.setIcon(icon_2171b65cde4c29d307798507e93f268f);
#
#
#             var marker_03ffb161c782eeb65b7234b675a0ec60 = L.marker(
#                 [35.079, -106.6169],
#                 {
# }
#             ).addTo(marker_cluster_204e1b130447a06d1e7044e02075247e);
#
#
#             var icon_11b543deee236d1efb53cd9e6712988d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_77e087a175cbc845012bd3037e3530c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f898006a8c0fdee0c119d0bf65a20a1 = $(`&lt;div id=&quot;html_7f898006a8c0fdee0c119d0bf65a20a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. PABLO GARCIA&lt;/div&gt;`)[0];
#                 popup_77e087a175cbc845012bd3037e3530c3.setContent(html_7f898006a8c0fdee0c119d0bf65a20a1);
#
#
#
#         marker_03ffb161c782eeb65b7234b675a0ec60.bindPopup(popup_77e087a175cbc845012bd3037e3530c3)
#         ;
#
#
#
#
#                 marker_03ffb161c782eeb65b7234b675a0ec60.setIcon(icon_11b543deee236d1efb53cd9e6712988d);
#
#
#             var marker_36d23ad9b3ed739d1b6680cef44e008c = L.marker(
#                 [35.5065, -108.7414],
#                 {
# }
#             ).addTo(marker_cluster_204e1b130447a06d1e7044e02075247e);
#
#
#             var icon_4ac6dd01ca7825a21963068c27670513 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fe6816ae07ae4c57a091cf40b9ab46ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eb0ffecdb025def037aab8226

# %%
from folium.plugins import MarkerCluster
from IPython.display import HTML

# 1. Build the map using CartoDB tiles (doesn't trigger the OSM 403 block)
nm_map = folium.Map(location=[34.512, -105.988], zoom_start=7, tiles="CartoDB positron")
marker_cluster = MarkerCluster(name="Nephrology").add_to(nm_map)

# 2. Map your 60 rows
for idx, row in df_nmneph.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

folium.LayerControl().add_to(nm_map)

# 3. Save it locally
output_file = "nm_nephrology_risk_map2.html"
nm_map.save(output_file)

# 4. THE OFFLINE WORKAROUND: Read the raw text of the file and force-inject it
with open(output_file, 'r', encoding='utf-8') as f:
    html_content = f.read()

# Display it inside the notebook by passing the raw HTML text string
HTML(f'<div style="width:100%; height:1000px;">{html_content}</div>')
# Out:
# <div style="width:100%; height:1000px;"><!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_c5c9c31194b35f3e950dc03c57e52080 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#             <style>html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             </style>
#
#             <style>#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             </style>
#
#             <script>
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             </script>
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js"></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css"/>
# </head>
# <body>
#
#
#             <div class="folium-map" id="map_c5c9c31194b35f3e950dc03c57e52080" ></div>
#
# </body>
# <script>
#
#
#             var map_c5c9c31194b35f3e950dc03c57e52080 = L.map(
#                 "map_c5c9c31194b35f3e950dc03c57e52080",
#                 {
#                     center: [34.512, -105.988],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   "zoom": 7,
#   "zoomControl": true,
#   "preferCanvas": false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c71f5f9df7f509f3eb0c126c458ff1f = L.tileLayer(
#                 "https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
#                 {
#   "minZoom": 0,
#   "maxZoom": 20,
#   "maxNativeZoom": 20,
#   "noWrap": false,
#   "attribution": "\u0026copy; \u003ca href=\"https://www.openstreetmap.org/copyright\"\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\"https://carto.com/attributions\"\u003eCARTO\u003c/a\u003e",
#   "subdomains": "abcd",
#   "detectRetina": false,
#   "tms": false,
#   "opacity": 1,
# }
#
#             );
#
#
#             tile_layer_7c71f5f9df7f509f3eb0c126c458ff1f.addTo(map_c5c9c31194b35f3e950dc03c57e52080);
#
#
#             var marker_cluster_d9696125b031662399d6d10fe3a22f6e = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_8d09f046a85aad6d87436c56d53ba2ef = L.marker(
#                 [35.1104, -106.5781],
#                 {
# }
#             ).addTo(marker_cluster_d9696125b031662399d6d10fe3a22f6e);
#
#
#             var icon_906b86f6247dfb89838742f9976b50ca = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_44408ecea35efcb595cd5c557f590ea0 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_b755aeb2e6c701ab0149c0bd7cc832d0 = $(`<div id="html_b755aeb2e6c701ab0149c0bd7cc832d0" style="width: 100.0%; height: 100.0%;">Dr. MAYBIN SIMFUKWE</div>`)[0];
#                 popup_44408ecea35efcb595cd5c557f590ea0.setContent(html_b755aeb2e6c701ab0149c0bd7cc832d0);
#
#
#
#         marker_8d09f046a85aad6d87436c56d53ba2ef.bindPopup(popup_44408ecea35efcb595cd5c557f590ea0)
#         ;
#
#
#
#
#                 marker_8d09f046a85aad6d87436c56d53ba2ef.setIcon(icon_906b86f6247dfb89838742f9976b50ca);
#
#
#             var marker_2d3f455255b28f2bce3e1b44a097c264 = L.marker(
#                 [35.079, -106.6169],
#                 {
# }
#             ).addTo(marker_cluster_d9696125b031662399d6d10fe3a22f6e);
#
#
#             var icon_8af53ac7493bb8421af474df5fa198d9 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_5d6ac03d67948a397c610be4e1aa4dbb = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_dd85435c5f24e70ae57069cc5db8d321 = $(`<div id="html_dd85435c5f24e70ae57069cc5db8d321" style="width: 100.0%; height: 100.0%;">Dr. PABLO GARCIA</div>`)[0];
#                 popup_5d6ac03d67948a397c610be4e1aa4dbb.setContent(html_dd85435c5f24e70ae57069cc5db8d321);
#
#
#
#         marker_2d3f455255b28f2bce3e1b44a097c264.bindPopup(popup_5d6ac03d67948a397c610be4e1aa4dbb)
#         ;
#
#
#
#
#                 marker_2d3f455255b28f2bce3e1b44a097c264.setIcon(icon_8af53ac7493bb8421af474df5fa198d9);
#
#
#             var marker_9ab3ad057cee6dd3e2737961507cca57 = L.marker(
#                 [35.5065, -108.7414],
#                 {
# }
#             ).addTo(marker_cluster_d9696125b031662399d6d10fe3a22f6e);
#
#
#             var icon_3152f667984c1c1a50f3258c2d76437b = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_433c2b912b8435a419ecb24efa1d3181 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_ed1890a2b1760511a63440b030cd8adf = $(`<div id="html_ed1890a2b1760511a63440b030cd8adf" style="width: 100.0%; height: 100.0%;">Dr. SUSHIL DESHMUKH</div>`)[0];
#                 popup_433c2b912b8435a419ecb24efa1d3181.setContent(html_ed1890a2b1760511a63440b030cd8adf);
#
#
#
#         marker_9ab3ad057cee6dd3e2737961507cca57.bindPopup(popup_433c2b912b8435a419ecb24efa1d3181)
#         ;
#
#
#
#
#                 marker_9ab3ad057cee6dd3e2737961507cca57.setIcon(icon_3152f667984c1c1a50f3258c2d76437b);
#
#
#             var marker_807efe7a91602d437ef3a4f0761b067a = L.marker(
#                 [35.5065, -108.7414],
#                 {
# }
#             ).addTo(marker_cluster_d9696125b031662399d6d10fe3a22f6e);
#
#
#             var icon_77b3b684ba731a436c45a0cd22a23fcb = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_ad9261c08430821a1d3592bd81430296 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_bd2f24c

# %% [markdown]
# ### Oncology

# %%
# Batch lookup coordinates using the series
geo_data = nomi.query_postal_code(df_nmonco['zip_5'].tolist())
geo_data
# Out:
#     postal_code country_code   place_name  state_name state_code county_name  \
# 0         88220           US     Carlsbad  New Mexico         NM        Eddy
# 1         87106           US  Albuquerque  New Mexico         NM  Bernalillo
# 2         87106           US  Albuquerque  New Mexico         NM  Bernalillo
# 3         87106           US  Albuquerque  New Mexico         NM  Bernalillo
# 4         88061           US  Silver City  New Mexico         NM       Grant
# ..          ...          ...          ...         ...        ...         ...
# 112       87110           US  Albuquerque  New Mexico         NM  Bernalillo
# 113       87110           US  Albuquerque  New Mexico         NM  Bernalillo
# 114       87125           US  Albuquerque  New Mexico         NM  Bernalillo
# 115       87125           US  Albuquerque  New Mexico         NM  Bernalillo
# 116       87125           US  Albuquerque  New Mexico         NM  Bernalillo
#
#      county_code community_name  community_code  latitude  longitude  accuracy
# 0           15.0           None             NaN   32.4119  -104.2395       4.0
# 1            1.0           None             NaN   35.0790  -106.6169       4.0
# 2            1.0           None             NaN   35.0790  -106.6169       4.0
# 3            1.0           None             NaN   35.0790  -106.6169       4.0
# 4           17.0           None             NaN   32.7900  -108.2749       4.0
# ..           ...            ...             ...       ...        ...       ...
# 112          1.0           None             NaN   35.1104  -106.5781       4.0
# 113          1.0           None             NaN   35.1104  -106.5781       4.0
# 114          1.0           None             NaN   35.0443  -106.6729       4.0
# 115          1.0           None             NaN   35.0443  -106.6729       4.0
# 116          1.0           None             NaN   35.0443  -106.6729       4.0
#
# [117 rows x 12 columns]

# %%
# Join coordinates and county names back to your dataframe
df_nmonco['latitude'] = geo_data['latitude'].values
df_nmonco['longitude'] = geo_data['longitude'].values
df_nmonco['county_name'] = geo_data['county_name'].values
# Out:
# /tmp/ipykernel_26849/755888557.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmonco['latitude'] = geo_data['latitude'].values
# /tmp/ipykernel_26849/755888557.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmonco['longitude'] = geo_data['longitude'].values
# /tmp/ipykernel_26849/755888557.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nmonco['county_name'] = geo_data['county_name'].values

# %%
# Drop any rows that couldn't be resolved
df_nmonco = df_nmonco.dropna(subset=['latitude', 'longitude'])

print(f"Successfully geocoded {len(df_nmonco)} providers via ZIP code centroids!")
# Out:
# Successfully geocoded 117 providers via ZIP code centroids!

# %%
from folium.plugins import MarkerCluster

# 1. Initialize map centered on New Mexico
nm_map = folium.Map(location=[34.5199, -105.8701], zoom_start=7)

# %%
# 3. Overlay the Cardiology Provider Markers using a Cluster layer for clean viewing
marker_cluster = MarkerCluster(name="Oncology").add_to(nm_map)

for idx, row in df_nmonco.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='heart', prefix='fa')
    ).add_to(marker_cluster)

# 4. Add layer controls so you can toggle views on/off
folium.LayerControl().add_to(nm_map)

# Save or display the map
nm_map.save("nm_oncology_risk_map.html")
nm_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9548250917342300caa722dc4bfc27e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9548250917342300caa722dc4bfc27e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9548250917342300caa722dc4bfc27e4 = L.map(
#                 &quot;map_9548250917342300caa722dc4bfc27e4&quot;,
#                 {
#                     center: [34.5199, -105.8701],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_70af1b811472c10ad54d6286a20378eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_70af1b811472c10ad54d6286a20378eb.addTo(map_9548250917342300caa722dc4bfc27e4);
#
#
#             var marker_cluster_c08e57770c0330008a2a19d878a5c98a = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_fa077206e079132dcc7ef61dac31c0d3 = L.marker(
#                 [32.4119, -104.2395],
#                 {
# }
#             ).addTo(marker_cluster_c08e57770c0330008a2a19d878a5c98a);
#
#
#             var icon_2ddd9b8ccf8876faf1c19677f9cd2f27 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_c029ea094f07e591d7e109f2326f9165 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02d9581bc1f5e2ae38ed15e284fcf607 = $(`&lt;div id=&quot;html_02d9581bc1f5e2ae38ed15e284fcf607&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. MASOUD KHORSAND-SAHBAIE&lt;/div&gt;`)[0];
#                 popup_c029ea094f07e591d7e109f2326f9165.setContent(html_02d9581bc1f5e2ae38ed15e284fcf607);
#
#
#
#         marker_fa077206e079132dcc7ef61dac31c0d3.bindPopup(popup_c029ea094f07e591d7e109f2326f9165)
#         ;
#
#
#
#
#                 marker_fa077206e079132dcc7ef61dac31c0d3.setIcon(icon_2ddd9b8ccf8876faf1c19677f9cd2f27);
#
#
#             var marker_cd75e3d6ac9c09a5e98ad8590376fd04 = L.marker(
#                 [35.079, -106.6169],
#                 {
# }
#             ).addTo(marker_cluster_c08e57770c0330008a2a19d878a5c98a);
#
#
#             var icon_dd4faaa1ff32d902433fae1018852c5a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_28e920a82f2c32e1cf2c555b36257328 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3ebdbb38509e7060af65c6a78fc6b32 = $(`&lt;div id=&quot;html_e3ebdbb38509e7060af65c6a78fc6b32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dr. ETHAN BINDER&lt;/div&gt;`)[0];
#                 popup_28e920a82f2c32e1cf2c555b36257328.setContent(html_e3ebdbb38509e7060af65c6a78fc6b32);
#
#
#
#         marker_cd75e3d6ac9c09a5e98ad8590376fd04.bindPopup(popup_28e920a82f2c32e1cf2c555b36257328)
#         ;
#
#
#
#
#                 marker_cd75e3d6ac9c09a5e98ad8590376fd04.setIcon(icon_dd4faaa1ff32d902433fae1018852c5a);
#
#
#             var marker_7d7adc6da7eb06c252b331194031d10e = L.marker(
#                 [35.079, -106.6169],
#                 {
# }
#             ).addTo(marker_cluster_c08e57770c0330008a2a19d878a5c98a);
#
#
#             var icon_7358423b3c752d17cf2c9b4ac93c8831 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;heart&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_dece50f604b32f757dceb96f6232566e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbc92edf2872e5b12f5

# %%
from folium.plugins import MarkerCluster
from IPython.display import HTML

# 1. Build the map using CartoDB tiles (doesn't trigger the OSM 403 block)
nm_map = folium.Map(location=[34.512, -105.988], zoom_start=7, tiles="CartoDB positron")
marker_cluster = MarkerCluster(name="Oncology").add_to(nm_map)

# 2. Map your 60 rows
for idx, row in df_nmonco.iterrows():
    popup_text = f"Dr. {row['Provider First Name']} {row['Provider Last Name']}"

    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=popup_text,
        icon=folium.Icon(color='blue', icon='info-sign')
    ).add_to(marker_cluster)

folium.LayerControl().add_to(nm_map)

# 3. Save it locally
output_file = "nm_oncology_risk_map2.html"
nm_map.save(output_file)

# 4. THE OFFLINE WORKAROUND: Read the raw text of the file and force-inject it
with open(output_file, 'r', encoding='utf-8') as f:
    html_content = f.read()

# Display it inside the notebook by passing the raw HTML text string
HTML(f'<div style="width:100%; height:1000px;">{html_content}</div>')
# Out:
# <div style="width:100%; height:1000px;"><!DOCTYPE html>
# <html>
# <head>
#
#     <meta http-equiv="content-type" content="text/html; charset=UTF-8" />
#     <script src="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js"></script>
#     <script src="https://code.jquery.com/jquery-3.7.1.min.js"></script>
#     <script src="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js"></script>
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js"></script>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css"/>
#     <link rel="stylesheet" href="https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css"/>
#     <link rel="stylesheet" href="https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css"/>
#
#             <meta name="viewport" content="width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
#             <style>
#                 #map_cbeadabade648fb8e93bc2c274b86d2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             </style>
#
#             <style>html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             </style>
#
#             <style>#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             </style>
#
#             <script>
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             </script>
#
#
#     <script src="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js"></script>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css"/>
#     <link rel="stylesheet" href="https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css"/>
# </head>
# <body>
#
#
#             <div class="folium-map" id="map_cbeadabade648fb8e93bc2c274b86d2f" ></div>
#
# </body>
# <script>
#
#
#             var map_cbeadabade648fb8e93bc2c274b86d2f = L.map(
#                 "map_cbeadabade648fb8e93bc2c274b86d2f",
#                 {
#                     center: [34.512, -105.988],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   "zoom": 7,
#   "zoomControl": true,
#   "preferCanvas": false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2b71fcabd41dfa2f0f4c77b2426d786 = L.tileLayer(
#                 "https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png",
#                 {
#   "minZoom": 0,
#   "maxZoom": 20,
#   "maxNativeZoom": 20,
#   "noWrap": false,
#   "attribution": "\u0026copy; \u003ca href=\"https://www.openstreetmap.org/copyright\"\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\"https://carto.com/attributions\"\u003eCARTO\u003c/a\u003e",
#   "subdomains": "abcd",
#   "detectRetina": false,
#   "tms": false,
#   "opacity": 1,
# }
#
#             );
#
#
#             tile_layer_d2b71fcabd41dfa2f0f4c77b2426d786.addTo(map_cbeadabade648fb8e93bc2c274b86d2f);
#
#
#             var marker_cluster_b62c31b9a3b70c8e375410ab3b22eace = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_3a8c9656e23b32edcd2c7b3b0f316b0e = L.marker(
#                 [32.4119, -104.2395],
#                 {
# }
#             ).addTo(marker_cluster_b62c31b9a3b70c8e375410ab3b22eace);
#
#
#             var icon_981b6b3b1adcc549913ab811290cdd44 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_a0b0c3f817227eaa63bd490a60f669ce = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_9d7d9754ed7d6d092ba8a8a1b668d4c4 = $(`<div id="html_9d7d9754ed7d6d092ba8a8a1b668d4c4" style="width: 100.0%; height: 100.0%;">Dr. MASOUD KHORSAND-SAHBAIE</div>`)[0];
#                 popup_a0b0c3f817227eaa63bd490a60f669ce.setContent(html_9d7d9754ed7d6d092ba8a8a1b668d4c4);
#
#
#
#         marker_3a8c9656e23b32edcd2c7b3b0f316b0e.bindPopup(popup_a0b0c3f817227eaa63bd490a60f669ce)
#         ;
#
#
#
#
#                 marker_3a8c9656e23b32edcd2c7b3b0f316b0e.setIcon(icon_981b6b3b1adcc549913ab811290cdd44);
#
#
#             var marker_acd9ecef65bcac9afce975efeee60ad5 = L.marker(
#                 [35.079, -106.6169],
#                 {
# }
#             ).addTo(marker_cluster_b62c31b9a3b70c8e375410ab3b22eace);
#
#
#             var icon_6bfeaee355d5106522e968ce8108aed8 = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_de77344c3cf974032e9adcdea49a2639 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_eb21d736e07b3b2066569bc462fa16ba = $(`<div id="html_eb21d736e07b3b2066569bc462fa16ba" style="width: 100.0%; height: 100.0%;">Dr. ETHAN BINDER</div>`)[0];
#                 popup_de77344c3cf974032e9adcdea49a2639.setContent(html_eb21d736e07b3b2066569bc462fa16ba);
#
#
#
#         marker_acd9ecef65bcac9afce975efeee60ad5.bindPopup(popup_de77344c3cf974032e9adcdea49a2639)
#         ;
#
#
#
#
#                 marker_acd9ecef65bcac9afce975efeee60ad5.setIcon(icon_6bfeaee355d5106522e968ce8108aed8);
#
#
#             var marker_e826809d806095ef944a7590c9bf0184 = L.marker(
#                 [35.079, -106.6169],
#                 {
# }
#             ).addTo(marker_cluster_b62c31b9a3b70c8e375410ab3b22eace);
#
#
#             var icon_9106eb1e91afd85b34e769360f7a7dda = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_20e95dfee953c51bb13830c15961b881 = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_88704da1ea8b843d9b60992cd48959a5 = $(`<div id="html_88704da1ea8b843d9b60992cd48959a5" style="width: 100.0%; height: 100.0%;">Dr. ATUL KUMAR</div>`)[0];
#                 popup_20e95dfee953c51bb13830c15961b881.setContent(html_88704da1ea8b843d9b60992cd48959a5);
#
#
#
#         marker_e826809d806095ef944a7590c9bf0184.bindPopup(popup_20e95dfee953c51bb13830c15961b881)
#         ;
#
#
#
#
#                 marker_e826809d806095ef944a7590c9bf0184.setIcon(icon_9106eb1e91afd85b34e769360f7a7dda);
#
#
#             var marker_7598e7110f366d09f1f9bfc267893c69 = L.marker(
#                 [35.079, -106.6169],
#                 {
# }
#             ).addTo(marker_cluster_b62c31b9a3b70c8e375410ab3b22eace);
#
#
#             var icon_a535d5905b905e1ae3f3076df5dc8b1a = L.AwesomeMarkers.icon(
#                 {
#   "markerColor": "blue",
#   "iconColor": "white",
#   "icon": "info-sign",
#   "prefix": "glyphicon",
#   "extraClasses": "fa-rotate-0",
# }
#             );
#
#
#         var popup_9e89de5e5a7bf8d1e4441360f7c6ff6a = L.popup({
#   "maxWidth": "100%",
# });
#
#
#
#                 var html_94550f
